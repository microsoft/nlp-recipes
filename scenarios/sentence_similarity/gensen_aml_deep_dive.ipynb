# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Training GenSen on AzureML: Deep Dive

# %% [markdown]
# ## Introduction
# GenSen is a technique to learn general purpose, fixed-length representations of sentences via multi-task training.  The model combines the benefits of diverse sentence representation learning objectives into a single multi-task framework. As described in the paper **Learning General Purpose Distributed Sentence Representations via Large Scale Multi-task Learning**, it is "the first large-scale reusable sentence representation model obtained by combining a set of training objectives with the level of diversity explored here, i.e. multi-lingual NMT, natural language inference, constituency parsing and skip-thought vectors" [\[1\]](#References). These representations are useful for transfer and low-resource learning. GenSen is trained on several data sources with multiple training objectives on over 100 milion sentences.
#
# GenSen yields the state-of-the-art results on multiple datasets, such as MRPC, SICK-R, SICK-E and STS, for sentence similarity. The reported results are as follows compared with other models [\[3\]](#References):
#
# | Model | MRPC | SICK-R | SICK-E | STS |
# | --- | --- | --- | --- | --- |
# | GenSen (Subramanian et al., 2018) | 78.6/84.4 | 0.888 | 87.8 | 78.9/78.6 |
# | [InferSent](https://arxiv.org/abs/1705.02364) (Conneau et al., 2017) | 76.2/83.1 | 0.884 | 86.3 | 75.8/75.5 |
# | [TF-KLD](https://www.aclweb.org/anthology/D13-1090) (Ji and Eisenstein, 2013) | 80.4/85.9 | - | - | - |
#
# This notebook serves as an introduction to an end-to-end NLP solution for sentence similarity by demonstrating how to train and tune GenSen on the AzureML platform.

# %% [markdown]
# ## Background: Sequence-to-Sequence Learning
# ![Sequence to sequence learning examples: machine translation (left) and constituent parsing (right)](https://nlpbp.blob.core.windows.net/images/seq2seq.png)**Sequence to sequence learning examples: machine translation (left) and constituent parsing (right)**
#
# The GenSen model is known to be most similar to that of Luong et al. (2015) [\[4\]](#References), who train a many-to-many **sequence-to-sequence** model on a diverse set of weakly related tasks that includes machine translation, constituency parsing, image captioning, sequence autoencoding, and intra-sentence skip-thoughts.
#
# Sequence-to-sequence learning, or seq2seq, aims to directly model the conditional probability $p(x|y)$ of mapping an input sequence, $x_1,...,x_n$, into an output sequence, $y_1,...,y_m$. This is done using an encoder-decoder framework. As illustrated in the above figure, the encoder computes a representation $s$ for each input sequence,  which the *decoder* uses to generate the ouput sequence. This decomposes the conditional probability as" [\[4\]](#References):
# $$
# \log p(y|x)=\sum_{j=1}^{m} \log p(y_i|y_{<j}, x, s)
# $$
#
# It is worth noting that the GenSen model deviates from Luong's seq2seq method in two key ways. First, GenSen uses an attention mechanism, meaning that the learned vector representations are not of fixed length. Second, GenSen optimizes for improvements on the same tasks on which the model is trained, rather than optimizing for transferability to different tasks or domains. [\[1\]](#References)

# %% [markdown]
# # 0 Global Settings

# %%
import sys
import time
import os
import pandas as pd
import shutil

sys.path.append("../../")
from utils_nlp.dataset import snli, preprocess, Split
from utils_nlp.azureml import azureml_utils
from utils_nlp.gensen.preprocess_utils import gensen_preprocess

import azureml as aml
import azureml.train.hyperdrive as hd
from azureml.telemetry import set_diagnostics_collection
import azureml.data
from azureml.data.azure_storage_datastore import AzureFileDatastore
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core import Experiment, get_run
from azureml.core.runconfig import MpiConfiguration
from azureml.train.dnn import PyTorch
from azureml.train.estimator import Estimator
from azureml.train.hyperdrive import (
    RandomParameterSampling,
    BanditPolicy,
    HyperDriveConfig,
    uniform,
    PrimaryMetricGoal,
)
from azureml.widgets import RunDetails

print("System version: {}".format(sys.version))
print("Azure ML SDK Version:", aml.core.VERSION)
print("Pandas version: {}".format(pd.__version__))
# Out:
# System version: 3.6.8 |Anaconda, Inc.| (default, Dec 29 2018, 19:04:46)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# Azure ML SDK Version: 1.0.48
# Pandas version: 0.24.2

# %%
CACHE_DIR = "./temp"
AZUREML_CONFIG_PATH = "./.azureml"
AZUREML_VERBOSE = False  # Prints verbose azureml logs when True

# %% [markdown]
# In this notebook we use the Azure Machine Learning Python SDK to facilitate remote training and computation. To get started, we must first initialize an AzureML [Workspace](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#workspace), a centralized resource for managing experiment runs, compute resources, datastores, and other machine learning artifacts on the cloud. Refer to the official [configuration](https://github.com/Azure/MachineLearningNotebooks/blob/master/configuration.ipynb) notebook for more information about setting up the workspace.

# %%
if os.path.exists(AZUREML_CONFIG_PATH):
    ws = azureml_utils.get_or_create_workspace(config_path=AZUREML_CONFIG_PATH)
else:
    ws = azureml_utils.get_or_create_workspace(
        config_path=AZUREML_CONFIG_PATH,
        subscription_id="<SUBSCRIPTION_ID>",
        resource_group="<RESOURCE_GROUP>",
        workspace_name="<WORKSPACE_NAME>",
        workspace_region="<WORKSPACE_REGION>",
    )

if AZUREML_VERBOSE:
    print("Workspace name: {}".format(ws.name))
    print("Azure region: {}".format(ws.location))
    print("Subscription id: {}".format(ws.subscription_id))
    print("Resource group: {}".format(ws.resource_group))

# %% [markdown]
# Opt-in diagnostics for better experience, quality, and security of future releases.

# %%
set_diagnostics_collection(send_diagnostics=True)
# Out:
# Turning diagnostics collection on.

# %% [markdown]
# # 1 Data Loading and Preprocessing

# %% [markdown]
# We use the [SNLI](https://nlp.stanford.edu/projects/snli/) dataset in this example.
#
# Note: The dataset used in the original paper can be downloaded by running the bashfile [here](https://github.com/Maluuba/gensen/blob/master/get_data.sh). Training on the original datasets will reproduce the results in the [paper](https://arxiv.org/abs/1804.00079), but **will take about 20 hours of training time**. For the purposes of this example we use SNLI, a subset of the original dataset, as the only training dataset.

# %% [markdown]
# ## 1.1 Load SNLI

# %%
data_dir = os.path.join(CACHE_DIR, "data")
train = snli.load_pandas_df(data_dir, file_split=Split.TRAIN)
dev = snli.load_pandas_df(data_dir, file_split=Split.DEV)
test = snli.load_pandas_df(data_dir, file_split=Split.TEST)

# %%
train.head()
# Out:
#       gold_label                             sentence1_binary_parse  \
# 0        neutral  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 1  contradiction  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 2     entailment  ( ( ( A person ) ( on ( a horse ) ) ) ( ( jump...
# 3        neutral  ( Children ( ( ( smiling and ) waving ) ( at c...
# 4     entailment  ( Children ( ( ( smiling and ) waving ) ( at c...
#
#                               sentence2_binary_parse  \
# 0  ( ( A person ) ( ( is ( ( training ( his horse...
# 1  ( ( A person ) ( ( ( ( is ( at ( a diner ) ) )...
# 2  ( ( A person ) ( ( ( ( is outdoors ) , ) ( on ...
# 3  ( They ( are ( smiling ( at ( their parents ) ...
# 4             ( There ( ( are children ) present ) )
#
#                                      sentence1_parse  \
# 0  (ROOT (S (NP (NP (DT A) (NN person)) (PP (IN o...
# 1  (ROOT (S (NP (NP (DT A) (NN person)) (PP (IN o...
# 2  (ROOT (S (NP (NP (DT A) (NN person)) (PP (IN o...
# 3  (ROOT (NP (S (NP (NNP Children)) (VP (VBG smil...
# 4  (ROOT (NP (S (NP (NNP Children)) (VP (VBG smil...
#
#                                      sentence2_parse  \
# 0  (ROOT (S (NP (DT A) (NN person)) (VP (VBZ is) ...
# 1  (ROOT (S (NP (DT A) (NN person)) (VP (VBZ is) ...
# 2  (ROOT (S (NP (DT A) (NN person)) (VP (VBZ is) ...
# 3  (ROOT (S (NP (PRP They)) (VP (VBP are) (VP (VB...
# 4  (ROOT (S (NP (EX There)) (VP (VBP are) (NP (NN...
#
#                                            sentence1  \
# 0  A person on a horse jumps over a broken down a...
# 1  A person on a horse jumps over a broken down a...
# 2  A person on a horse jumps over a broken down a...
# 3              Children smiling and waving at camera
# 4              Children smiling and waving at camera
#
#                                            sentence2         captionID  \
# 0  A person is training his horse for a competition.  3416050480.jpg#4
# 1      A person is at a diner, ordering an omelette.  3416050480.jpg#4
# 2                  A person is outdoors, on a horse.  3416050480.jpg#4
# 3                  They are smiling at their parents  2267923837.jpg#2
# 4                         There are children present  2267923837.jpg#2
#
#                 pairID         label1 label2 label3 label4 label5
# 0  3416050480.jpg#4r1n        neutral    NaN    NaN    NaN    NaN
# 1  3416050480.jpg#4r1c  contradiction    NaN    NaN    NaN    NaN
# 2  3416050480.jpg#4r1e     entailment    NaN    NaN    NaN    NaN
# 3  2267923837.jpg#2r1n        neutral    NaN    NaN    NaN    NaN
# 4  2267923837.jpg#2r1e     entailment    NaN    NaN    NaN    NaN

# %% [markdown]
# ## 1.2 Tokenize

# %% [markdown]
# Here we clean the dataframes, do lowercase standardization, and tokenize the text using the [NLTK](https://www.nltk.org/) library.

# %%
def clean_and_tokenize(df):
    df = snli.clean_cols(df)
    df = snli.clean_rows(df)
    df = preprocess.to_lowercase(df)
    df = preprocess.to_nltk_tokens(df)
    return df

# %%
train = clean_and_tokenize(train)
dev = clean_and_tokenize(dev)
test = clean_and_tokenize(test)

# %%
train.head()
# Out:
#            score                                          sentence1  \
# 0        neutral  a person on a horse jumps over a broken down a...
# 1  contradiction  a person on a horse jumps over a broken down a...
# 2     entailment  a person on a horse jumps over a broken down a...
# 3        neutral              children smiling and waving at camera
# 4     entailment              children smiling and waving at camera
#
#                                            sentence2  \
# 0  a person is training his horse for a competition.
# 1      a person is at a diner, ordering an omelette.
# 2                  a person is outdoors, on a horse.
# 3                  they are smiling at their parents
# 4                         there are children present
#
#                                     sentence1_tokens  \
# 0  [a, person, on, a, horse, jumps, over, a, brok...
# 1  [a, person, on, a, horse, jumps, over, a, brok...
# 2  [a, person, on, a, horse, jumps, over, a, brok...
# 3       [children, smiling, and, waving, at, camera]
# 4       [children, smiling, and, waving, at, camera]
#
#                                     sentence2_tokens
# 0  [a, person, is, training, his, horse, for, a, ...
# 1  [a, person, is, at, a, diner, ,, ordering, an,...
# 2      [a, person, is, outdoors, ,, on, a, horse, .]
# 3           [they, are, smiling, at, their, parents]
# 4                    [there, are, children, present]

# %% [markdown]
# ## 1.3 Preprocess
# We format our data in a specific way in order for the Gensen model to be able to ingest it. We do this by
# * Saving the tokens for each split in a `snli_1.0_{split}.txt.clean` file, with the sentence pairs and scores tab-separated and the tokens separated by a single space. Since some of the samples have invalid scores ("-"), we filter those out and save them separately in a `snli_1.0_{split}.txt.clean.noblank` file.
# * Saving the tokenized sentence and labels separately, in the form `snli_1.0_{split}.txt.s1.tok` or `snli_1.0_{split}.txt.s2.tok` or `snli_1.0_{split}.txt.lab`.

# %%
preprocessed_data_dir = gensen_preprocess(train, dev, test, data_dir)
print("Writing input data to {}".format(preprocessed_data_dir))
# Out:
# Writing input data to ./temp/data/clean/snli_1.0

# %% [markdown]
# ## 1.4 Upload to Azure Blob Storage
# We upload the data from the local machine into the datastore so that it can be accessed for remote training. The datastore is a reference that points to a storage account, e.g. the Azure Blob Storage service. It can be attached to an AzureML workspace to facilitate data management operations such as uploading/downloading data or interacting with data from remote compute targets.
#
# **Note: If you already have the preprocessed files under `clean/snli_1.0/` in your default datastore, you DO NOT need to redo this section.**

# %%
ds = ws.get_default_datastore()

if AZUREML_VERBOSE:
    print("Datastore type: {}".format(ds.datastore_type))
    print("Datastore account: {}".format(ds.account_name))
    print("Datastore container: {}".format(ds.container_name))
    print("Data reference: {}".format(ds.as_mount()))

# %%
_ = ds.upload(
    src_dir=os.path.join(data_dir, "clean/snli_1.0"),
    overwrite=False,
    show_progress=AZUREML_VERBOSE,
)

# %% [markdown]
# # 2 Train GenSen with Distributed Pytorch and Horovod on AzureML
# In this tutorial, we train a GenSen model with PyTorch on AML using distributed training across a GPU cluster.
#
# After creating the workspace and setting up the development environment, training a model in Azure Machine Learning involves the following steps:
# 1. Creating a remote compute target
# 2. Preparing the training data and uploading it to datastore (Note that this was done in Section 1.4)
# 3. Preparing the training script
# 4. Creating Estimator and Experiment objects
# 5. Submitting the Estimator to an Experiment attached to the AzureML workspace

# %% [markdown]
# ## 2.1 Create a Remote Compute Target
# We create and attach a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for training the model. Here we use the AzureML-managed compute target ([AmlCompute](https://docs.microsoft.com/azure/machine-learning/service/how-to-set-up-training-targets#amlcompute)) as our remote training compute resource. Our cluster autoscales from 0 to 2 `STANDARD_NC6` GPU nodes.
#
# Creating and configuring the AmlCompute cluster takes approximately 5 minutes the first time around. Once a cluster with the given configuration is created, it does not need to be created again.
#
# As with other Azure services, there are limits on certain resources (e.g. AmlCompute) associated with the Azure Machine Learning service. Read more about the default limits and how to request more quota [here](https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-manage-quotas).

# %%
cluster_name = "gensen-mlflow"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print("Found existing compute target {}".format(cluster_name))
except ComputeTargetException:
    print("Creating a new compute target {}...".format(cluster_name))
    compute_config = AmlCompute.provisioning_configuration(
        vm_size="STANDARD_NC6", max_nodes=2
    )
    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
    compute_target.wait_for_completion(show_output=AZUREML_VERBOSE)

if AZUREML_VERBOSE:
    print(compute_target.get_status().serialize())
# Out:
# Found existing compute target gensen-mlflow

# %% [markdown]
# ## 2.2 Prepare the Training Script
# The training process involves the following steps:
# 1. Create or load the dataset vocabulary
# 2. Train on the training dataset for each batch epoch (batch size = 48 updates)
# 3. Evaluate on the validation dataset for every 10 epochs
# 4. Find the local minimum point on validation loss
# 5. Save the best model and stop the training process
#
# In this section, we define the training script and move all necessary dependencies to `project_folder`, which will eventually be submitted to the remote compute target. Note that the size of the folder can not exceed 300Mb, so large dependencies such as pre-trained embeddings must be accessed from the datastore.

# %%
project_folder = os.path.join(CACHE_DIR, "gensen")
os.makedirs(project_folder, exist_ok=True)

# %% [markdown]
# The script for distributed GenSen training is provided at `./gensen_train.py`.
#
# In this example, we use MLflow to log metrics. We also use the [AzureML-Mlflow](https://pypi.org/project/azureml-mlflow/) package to persist these metrics to the AzureML workspace. This is done with no change to the provided training script! Note that logging is done for loss *per minibatch*.

# %% [markdown]
# Copy the training script `gensen_train.py` and config file `gensen_config.json` into the project folder.

# %%
utils_folder = os.path.join(project_folder, "utils_nlp")

# %%
_ = shutil.copytree("../../utils_nlp", utils_folder)

# %%
_ = shutil.copy("gensen_train.py", os.path.join(utils_folder, "gensen"))
_ = shutil.copy("gensen_config.json", os.path.join(utils_folder, "gensen"))

# %% [markdown]
# ## 2.3 Define the Estimator and Experiment

# %% [markdown]
# ### 2.3.1 Create a PyTorch Estimator
# The Azure ML SDK's PyTorch Estimator allows us to submit PyTorch training jobs for both single-node and distributed runs. For more information on the PyTorch estimator, refer [here](https://docs.microsoft.com/azure/machine-learning/service/how-to-train-pytorch).
#
# Note that `gensen_config.json` defines all the hyperparameters and paths when training GenSen model. The trained model will be saved in `models` to Azure Blob Storage. **Remember to clean the `models` folder in order to save new models.**

# %%
script_params = {
    "--config": "utils_nlp/gensen/gensen_config.json",
    "--data_folder": ws.get_default_datastore().as_mount(),
}

estimator = PyTorch(
    source_directory=project_folder,
    script_params=script_params,
    compute_target=compute_target,
    entry_script="utils_nlp/gensen/gensen_train.py",
    node_count=2,
    process_count_per_node=1,
    distributed_training=MpiConfiguration(),
    use_gpu=True,
    framework_version="1.1",
    conda_packages=["scikit-learn=0.20.3", "h5py", "nltk"],
    pip_packages=["azureml-mlflow>=1.0.43.1", "numpy>=1.16.0"],
)

# %% [markdown]
# This Estimator specifies that the training script will run on `2` nodes, with one worker per node. In order to execute a distributed run using GPU, we must define `use_gpu` and `distributed_backend` to use MPI/Horovod. PyTorch, Horovod, and other necessary dependencies are installed automatically. If the training script makes use of packages that are not already defined in `.azureml/conda_dependencies.yml`, we must explicitly tell the estimator to install them via the constructor's `pip_packages` or `conda_packages` parameters.
#
# Note that if the estimator is being created for the first time, this step will take longer to run because the conda dependencies found under `.azureml/conda_dependencies.yml` must be installed from scratch. After the first run, it will use the existing conda environment and run the code directly.
#
# **Requirements:**
# - python=3.6.2
# - numpy=1.15.1
# - numpy-base=1.15.1
# - pip=10.0.1
# - python=3.6.6
# - python-dateutil=2.7.3
# - scikit-learn=0.20.3
# - azureml-defaults
# - h5py
# - nltk

# %% [markdown]
# ### 2.3.2 Create the Experiment
# Create an [Experiment](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) to track all the runs in the AzureML workspace for this tutorial.

# %%
experiment_name = "pytorch-gensen"
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## 2.4 Submit the Training Job to the Compute Target
# We can run the experiment by simply submitting the Estimator object to the compute target. Note that this call is asynchronous.

# %%
run = experiment.submit(estimator)
if AZUREML_VERBOSE:
    print(run)

# %% [markdown]
# ### 2.4.1 Monitor the Run
# We can monitor the progress of the run with a Jupyter widget. Like the run submission, the widget is asynchronous and provides live updates every 10-15 seconds until the job completes. The widget automatically plots and visualizes the loss metric that we logged to the AzureML workspace.

# %%
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO', 's…

# %%
_ = run.wait_for_completion(show_output=True) # Block until the script has completed training.
# Out:
# RunId: pytorch-gensen_1562904169_d0dbdced
# Web View: https://mlworkspace.azure.ai/portal/subscriptions/15ae9cb6-95c1-483d-a0e3-b1a1a3b06324/resourceGroups/nlprg/providers/Microsoft.MachineLearningServices/workspaces/jihon/experiments/pytorch-gensen/runs/pytorch-gensen_1562904169_d0dbdced
#
# Streaming azureml-logs/70_driver_log_rank_0.txt
# ===============================================
#
# 2019-07-12 04:47:32,862 - INFO - Finished creating iterator ...
# 2019-07-12 04:47:32,862 - INFO - Model Parameters :
# 2019-07-12 04:47:32,863 - INFO - Task : multi-seq2seq-nli
# 2019-07-12 04:47:32,863 - INFO - Source Word Embedding Dim  : 512
# 2019-07-12 04:47:32,863 - INFO - Target Word Embedding Dim  : 512
# 2019-07-12 04:47:32,863 - INFO - Source RNN Hidden Dim  : 2048
# 2019-07-12 04:47:32,863 - INFO - Target RNN Hidden Dim  : 2048
# 2019-07-12 04:47:32,863 - INFO - Source RNN Bidirectional  : True
# 2019-07-12 04:47:32,864 - INFO - Batch Size : 48
# 2019-07-12 04:47:32,864 - INFO - Optimizer : adam
# 2019-07-12 04:47:32,864 - INFO - Learning Rate : 0.000100
# 2019-07-12 04:47:32,864 - INFO - Found 19966 words in source :
# 2019-07-12 04:47:32,864 - INFO - Found 30004 target words in task snli
# 2019-07-12 04:47:32,864 - INFO - Found 19966 words in src
# 2019-07-12 04:47:32,864 - INFO - Found 30004 words in trg
# /azureml-envs/azureml_5567d9479ae0428ed93970775bca35cc/lib/python3.6/site-packages/torch/nn/modules/rnn.py:54: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.8 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# 2019-07-12 04:47:45,485 - INFO - MultitaskModel(
#   (src_embedding): Embedding(19966, 512, padding_idx=1)
#   (encoder): GRU(512, 1024, batch_first=True, dropout=0.8, bidirectional=True)
#   (enc_drp): Dropout(p=0.8)
#   (trg_embedding): ModuleList(
#     (0): Embedding(30004, 512, padding_idx=1)
#   )
#   (decoders): ModuleList(
#     (0): ConditionalGRU(
#       (input_weights): Linear(in_features=512, out_features=6144, bias=True)
#       (hidden_weights): Linear(in_features=2048, out_features=6144, bias=True)
#       (peep_weights): Linear(in_features=2048, out_features=6144, bias=True)
#     )
#   )
#   (decoder2vocab): ModuleList(
#     (0): Linear(in_features=2048, out_features=30004, bias=True)
#   )
#   (nli_decoder): Sequential(
#     (0): Dropout(p=0.3)
#     (1): Linear(in_features=8192, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=3, bias=True)
#   )
# )
# 2019-07-12 04:47:45,487 - INFO - OS Environ:
#  environ({'CUDNN_VERSION': '7.5.0.56', 'PMIX_ID': '2961047553.0', 'OMPI_COMM_WORLD_RANK': '0', 'PMIX_NAMESPACE': '2961047553', 'AZ_BATCHAI_JOB_WORKSPACE_NAME': 'jihon', 'AZUREML_SERVICE_ENDPOINT': 'https://eastus.experiments.azureml.net', 'AZ_BATCHAI_JOB_SUBSCRIPTION_ID': '15ae9cb6-95c1-483d-a0e3-b1a1a3b06324', 'AZ_BATCHAI_TASK_INDEX': '0', 'HOSTNAME': '19b1b8ea407f4459b33804a0c72b819c000001', 'AZUREML_CONTEXT_MANAGER_PROJECTPYTHONPATH': 'bnVsbA==', 'AZ_BATCHAI_CONFIG_UseBlobStreamer': 'false', 'AZ_BATCH_TASK_DIR': '/mnt/batch/tasks/workitems/563873cb-0930-4222-b000-78def2dff150/job-1/pytorch-gensen_156290416_880bcbff-b0e0-490f-8157-1cbc3b397c86', 'AZUREML_RUN_ID': 'pytorch-gensen_1562904169_d0dbdced', 'NVIDIA_REQUIRE_CUDA': 'cuda>=10.0 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=410,driver<411', 'OMPI_MCA_pmix': '^s1,s2,cray,isolated', 'OMPI_MCA_orte_ess_num_procs': '2', 'AZ_BATCHAI_JOB_TEMP': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/wd', 'NCCL_SOCKET_IFNAME': 'eth0', 'AZUREML_LOGDIRECTORY_PATH': 'azureml-logs/', 'OMPI_MCA_ess_base_vpid': '0', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs', 'OMPI_MCA_ess_base_jobid': '2961047553', 'PYTHONUNBUFFERED': 'True', 'PMIX_RANK': '0', 'AZUREML_ARM_PROJECT_NAME': 'pytorch-gensen', 'AZUREML_RUN_HISTORY_SERVICE_ENDPOINT': 'https://eastus.experiments.azureml.net', 'OLDPWD': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts/workspaceblobstore/azureml/pytorch-gensen_1562904169_d0dbdced', 'OMPI_MCA_orte_launch': '1', 'OMPI_MCA_orte_num_nodes': '2', 'AZ_BATCHAI_CLUSTER_SUBSCRIPTION_ID': '15ae9cb6-95c1-483d-a0e3-b1a1a3b06324', 'OMPI_COMM_WORLD_LOCAL_RANK': '0', 'OMPI_MCA_orte_hnp_uri': '2961047552.0;tcp://10.0.0.5,172.17.0.1:33513', 'AZ_BATCHAI_EXPERIMENT_NAME': 'azureml', 'OMPI_ARGV': '-task runTaskLet -taskId 9F6C9026D50319D1', 'OMPI_MCA_initial_wdir': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts/workspaceblobstore/azureml/pytorch-gensen_1562904169_d0dbdced', 'LC_ALL': 'C.UTF-8', 'AZ_BATCHAI_INPUT_AZUREML': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts/workspaceblobstore/azureml', 'AZUREML_JOBRELEASELOG_PATH': 'azureml-logs/job_release_log.txt', 'LD_LIBRARY_PATH': '/azureml-envs/azureml_5567d9479ae0428ed93970775bca35cc/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/cuda/lib64:/usr/local/cuda/extras/CUPTI/lib64', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LS_COLORS': '', 'OMPI_UNIVERSE_SIZE': '2', 'AZUREML_DISCOVERY_SERVICE_ENDPOINT': 'https://eastus.experiments.azureml.net/discovery', 'AZUREML_COMMUNICATOR': 'Mpi', 'AZ_BATCHAI_HOST_TOOLS_URL': 'https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D', 'AZ_BATCH_NODE_STARTUP_DIR': '/mnt/batch/tasks/startup', 'OMPI_MCA_mpi_yield_when_idle': '0', 'AZ_BATCHAI_JOB_WORK_DIR': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts/workspaceblobstore/azureml/pytorch-gensen_1562904169_d0dbdced', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'OMPI_COMMAND': 'hosttools', 'OMPI_MCA_btl_tcp_if_exclude': 'lo,docker0,eth1', 'OMPI_FILE_LOCATION': '/tmp/ompi.19b1b8ea407f4459b33804a0c72b819c000001.0/pid.112/0/0', 'OMPI_APP_CTX_NUM_PROCS': '2', 'AZUREML_RUN_TOKEN_EXPIRY': '1563508973', 'AZ_BATCH_TASK_SHARED_DIR': '/mnt/batch/tasks/workitems/563873cb-0930-4222-b000-78def2dff150/job-1/pytorch-gensen_156290416_880bcbff-b0e0-490f-8157-1cbc3b397c86', 'AZUREML_TARGET_TYPE': 'batchai', 'OMPI_MCA_orte_abort_on_non_zero_status': '1', 'PMIX_PTL_MODULE': 'tcp,usock', 'AZ_BATCHAI_CONFIG_ConfigureContainerUsingLocalPackage': 'true', 'AZ_BATCHAI_JOB_MOUNT_ROOT': '/mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts', 'AZUREML_CONTEXT_MANAGER_TRACKUSERERROR': 'bnVsbA==', 'PMIX_SERVER_URI21': '29610 ...
#
#
# 2019-07-12 04:47:45,542 - INFO - Commencing Training ...
# utils_nlp/gensen/gensen_train.py:428: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), 1.0)
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.0.5<0>
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO NCCL_IB_DISABLE set by environment to 1.
# NCCL version 2.4.2+cuda10.0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Setting affinity for GPU 0 to 3f
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO comm 0x7f54fc2e6160 rank 0 nranks 2 cudaDev 0 nvmlDev 0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO NCCL_TREE_THRESHOLD set by environment to 0.
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PXB
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Channel 00 :    0   1
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Channel 01 :    0   1
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Ring 00 : 1 -> 0 [receive] via NET/Socket/0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Ring 00 : 0 -> 1 [send] via NET/Socket/0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Ring 01 : 1 -> 0 [receive] via NET/Socket/0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Ring 01 : 0 -> 1 [send] via NET/Socket/0
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Using 128 threads, Min Comp Cap 3, Trees disabled
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO comm 0x7f54fc2e6160 rank 0 nranks 2 cudaDev 0 nvmlDev 0 - Init COMPLETE
# 19b1b8ea407f4459b33804a0c72b819c000001:135:159 [0] NCCL INFO Launch mode Parallel
# 2019-07-12 04:47:47,158 - INFO - Updates: 48
# /mnt/batch/tasks/shared/LS_root/jobs/jihon/azureml/pytorch-gensen_1562904169_d0dbdced/mounts/workspaceblobstore/azureml/pytorch-gensen_1562904169_d0dbdced/utils_nlp/gensen/utils.py:362: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   Variable(torch.LongTensor(sorted_src_lens), volatile=True)
# /azureml-envs/azureml_5567d9479ae0428ed93970775bca35cc/lib/python3.6/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /azureml-envs/azureml_5567d9479ae0428ed93970775bca35cc/lib/python3.6/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# utils_nlp/gensen/gensen_train.py:520: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), 1.0)
# 2019-07-12 04:47:49,227 - INFO - Updates: 96
# 2019-07-12 04:47:51,191 - INFO - Updates: 144
# 2019-07-12 04:47:52,774 - INFO - Updates: 192
# 2019-07-12 04:48:01,997 - INFO - Updates: 240
# 2019-07-12 04:48:04,142 - INFO - Updates: 288
# 2019-07-12 04:48:06,346 - INFO - Updates: 336
# 2019-07-12 04:48:07,985 - INFO - Updates: 384
# 2019-07-12 04:48:09,562 - INFO - Updates: 432
# 2019-07-12 04:48:11,126 - INFO - Updates: 480
# 2019-07-12 04:48:11,731 - INFO - Seq2Seq Examples Processed : 480 snli Loss : 9.73241 Num snli minibatches : 9
# 2019-07-12 04:48:11,842 - INFO - Round: 10 NLI Epoch : 0 NLI Examples Processed : 96 NLI Loss : 1.09730
# 2019-07-12 04:48:11,883 - INFO - Average time per minibatch : 2.38043
# 2019-07-12 04:48:11,978 - INFO - ############################
# 2019-07-12 04:48:11,978 - INFO - ##### Evaluating model #####
# 2019-07-12 04:48:11,978 - INFO - ############################
# 2019-07-12 04:49:37,081 - INFO - snli Validation Loss : 9.034
# 2019-07-12 04:49:37,082 - INFO - Best Validation Loss: 9.034465789794922
# 2019-07-12 04:49:37,082 - INFO - Monitor epoch: 1 Validation Loss:  9.034 Min Validation Epoch: 1 Loss : 9.034
# 2019-07-12 04:49:37,082 - INFO - Evaluating on NLI
# utils_nlp/gensen/gensen_train.py:241: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   f.softmax(class_logits).data.cpu().numpy().argmax(axis=-1)
# NLI Dev Acc : 0.32971
# utils_nlp/gensen/gensen_train.py:260: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   f.softmax(class_logits).data.cpu().numpy().argmax(axis=-1)
# NLI Test Acc : 0.32899
# 2019-07-12 04:49:52,810 - INFO - ******************************************************
# 2019-07-12 04:49:52,811 - INFO - Updates: 528
# 2019-07-12 04:49:56,378 - INFO - Updates: 576
# 2019-07-12 04:49:58,151 - INFO - Updates: 624
# 2019-07-12 04:50:01,017 - INFO - Updates: 672
# 2019-07-12 04:50:02,781 - INFO - Updates: 720
# 2019-07-12 04:50:05,256 - INFO - Updates: 768
# 2019-07-12 04:50:06,873 - INFO - Updates: 816
# 2019-07-12 04:50:09,120 - INFO - Updates: 864
# 2019-07-12 04:50:12,534 - INFO - Updates: 912
# 2019-07-12 04:50:14,107 - INFO - Updates: 960
# 2019-07-12 04:50:14,698 - INFO - Seq2Seq Examples Processed : 960 snli Loss : 7.83593 Num snli minibatches : 9
# 2019-07-12 04:50:14,840 - INFO - Round: 20 NLI Epoch : 0 NLI Examples Processed : 144 NLI Loss : 1.26046
# 2019-07-12 04:50:14,888 - INFO - Average time per minibatch : 2.18839
# 2019-07-12 04:50:14,929 - INFO - ############################
# 2019-07-12 04:50:14,930 - INFO - ##### Evaluating model #####
# 2019-07-12 04:50:14,930 - INFO - ############################
# 2019-07-12 04:51:39,678 - INFO - snli Validation Loss : 7.023
# 2019-07-12 04:51:39,679 - INFO - Best Validation Loss: 7.023276329040527
# 2019-07-12 04:51:39,679 - INFO - Monitor epoch: 2 Validation Loss:  7.023 Min Validation Epoch: 2 Loss : 7.023
# 2019-07-12 04:51:39,679 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.31823
# NLI Test Acc : 0.32105
# 2019-07-12 04:51:55,392 - INFO - ******************************************************
# 2019-07-12 04:51:55,392 - INFO - Updates: 1008
# 2019-07-12 04:51:58,059 - INFO - Updates: 1056
# 2019-07-12 04:52:02,436 - INFO - Updates: 1104
# 2019-07-12 04:52:04,076 - INFO - Updates: 1152
# 2019-07-12 04:52:05,586 - INFO - Updates: 1200
# 2019-07-12 04:52:07,333 - INFO - Updates: 1248
# 2019-07-12 04:52:13,005 - INFO - Updates: 1296
# 2019-07-12 04:52:15,112 - INFO - Updates: 1344
# 2019-07-12 04:52:17,059 - INFO - Updates: 1392
# 2019-07-12 04:52:18,980 - INFO - Updates: 1440
# 2019-07-12 04:52:20,266 - INFO - Seq2Seq Examples Processed : 1440 snli Loss : 6.07736 Num snli minibatches : 9
# 2019-07-12 04:52:20,357 - INFO - Round: 30 NLI Epoch : 0 NLI Examples Processed : 192 NLI Loss : 1.67492
# 2019-07-12 04:52:20,399 - INFO - Average time per minibatch : 2.48699
# 2019-07-12 04:52:20,440 - INFO - ############################
# 2019-07-12 04:52:20,440 - INFO - ##### Evaluating model #####
# 2019-07-12 04:52:20,440 - INFO - ############################
# 2019-07-12 04:53:45,608 - INFO - snli Validation Loss : 6.500
# 2019-07-12 04:53:45,609 - INFO - Best Validation Loss: 6.499959945678711
# 2019-07-12 04:53:45,609 - INFO - Monitor epoch: 3 Validation Loss:  6.500 Min Validation Epoch: 3 Loss : 6.500
# 2019-07-12 04:53:45,609 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.32869
# NLI Test Acc : 0.32767
# 2019-07-12 04:54:01,399 - INFO - ******************************************************
# 2019-07-12 04:54:01,399 - INFO - Updates: 1488
# 2019-07-12 04:54:04,921 - INFO - Updates: 1536
# 2019-07-12 04:54:09,631 - INFO - Updates: 1584
# 2019-07-12 04:54:11,168 - INFO - Updates: 1632
# 2019-07-12 04:54:13,428 - INFO - Updates: 1680
# 2019-07-12 04:54:14,984 - INFO - Updates: 1728
# 2019-07-12 04:54:16,468 - INFO - Updates: 1776
# 2019-07-12 04:54:18,533 - INFO - Updates: 1824
# 2019-07-12 04:54:21,429 - INFO - Updates: 1872
# 2019-07-12 04:54:23,499 - INFO - Updates: 1920
# 2019-07-12 04:54:24,104 - INFO - Seq2Seq Examples Processed : 1920 snli Loss : 5.79977 Num snli minibatches : 9
# 2019-07-12 04:54:24,154 - INFO - Round: 40 NLI Epoch : 0 NLI Examples Processed : 240 NLI Loss : 1.10170
# 2019-07-12 04:54:24,225 - INFO - Average time per minibatch : 2.27008
# 2019-07-12 04:54:24,276 - INFO - ############################
# 2019-07-12 04:54:24,276 - INFO - ##### Evaluating model #####
# 2019-07-12 04:54:24,277 - INFO - ############################
# 2019-07-12 04:55:49,193 - INFO - snli Validation Loss : 6.299
# 2019-07-12 04:55:49,193 - INFO - Best Validation Loss: 6.299232482910156
# 2019-07-12 04:55:49,193 - INFO - Monitor epoch: 4 Validation Loss:  6.299 Min Validation Epoch: 4 Loss : 6.299
# 2019-07-12 04:55:49,194 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33306
# NLI Test Acc : 0.34131
# 2019-07-12 04:56:04,901 - INFO - ******************************************************
# 2019-07-12 04:56:04,901 - INFO - Updates: 1968
# 2019-07-12 04:56:08,499 - INFO - Updates: 2016
# 2019-07-12 04:56:14,819 - INFO - Updates: 2064
# 2019-07-12 04:56:16,491 - INFO - Updates: 2112
# 2019-07-12 04:56:18,478 - INFO - Updates: 2160
# 2019-07-12 04:56:20,703 - INFO - Updates: 2208
# 2019-07-12 04:56:22,538 - INFO - Updates: 2256
# 2019-07-12 04:56:24,106 - INFO - Updates: 2304
# 2019-07-12 04:56:25,679 - INFO - Updates: 2352
# 2019-07-12 04:56:30,024 - INFO - Updates: 2400
# 2019-07-12 04:56:30,630 - INFO - Seq2Seq Examples Processed : 2400 snli Loss : 5.64057 Num snli minibatches : 9
# 2019-07-12 04:56:30,737 - INFO - Round: 50 NLI Epoch : 0 NLI Examples Processed : 288 NLI Loss : 1.08409
# 2019-07-12 04:56:30,817 - INFO - Average time per minibatch : 2.57247
# 2019-07-12 04:56:30,912 - INFO - ############################
# 2019-07-12 04:56:30,912 - INFO - ##### Evaluating model #####
# 2019-07-12 04:56:30,912 - INFO - ############################
# 2019-07-12 04:57:55,962 - INFO - snli Validation Loss : 6.215
# 2019-07-12 04:57:55,962 - INFO - Best Validation Loss: 6.215339183807373
# 2019-07-12 04:57:55,963 - INFO - Monitor epoch: 5 Validation Loss:  6.215 Min Validation Epoch: 5 Loss : 6.215
# 2019-07-12 04:57:55,963 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.34647
# NLI Test Acc : 0.34853
# 2019-07-12 04:58:11,719 - INFO - ******************************************************
# 2019-07-12 04:58:11,719 - INFO - Updates: 2448
# 2019-07-12 04:58:13,446 - INFO - Updates: 2496
# 2019-07-12 04:58:15,386 - INFO - Updates: 2544
# 2019-07-12 04:58:18,033 - INFO - Updates: 2592
# 2019-07-12 04:58:19,718 - INFO - Updates: 2640
# 2019-07-12 04:58:22,888 - INFO - Updates: 2688
# 2019-07-12 04:58:24,503 - INFO - Updates: 2736
# 2019-07-12 04:58:26,304 - INFO - Updates: 2784
# 2019-07-12 04:58:27,831 - INFO - Updates: 2832
# 2019-07-12 04:58:29,435 - INFO - Updates: 2880
# 2019-07-12 04:58:30,038 - INFO - Seq2Seq Examples Processed : 2880 snli Loss : 5.57434 Num snli minibatches : 9
# 2019-07-12 04:58:30,129 - INFO - Round: 60 NLI Epoch : 0 NLI Examples Processed : 336 NLI Loss : 1.14288
# 2019-07-12 04:58:30,173 - INFO - Average time per minibatch : 1.83152
# 2019-07-12 04:58:30,217 - INFO - ############################
# 2019-07-12 04:58:30,218 - INFO - ##### Evaluating model #####
# 2019-07-12 04:58:30,218 - INFO - ############################
# 2019-07-12 04:59:55,274 - INFO - snli Validation Loss : 6.190
# 2019-07-12 04:59:55,274 - INFO - Best Validation Loss: 6.190091609954834
# 2019-07-12 04:59:55,275 - INFO - Monitor epoch: 6 Validation Loss:  6.190 Min Validation Epoch: 6 Loss : 6.190
# 2019-07-12 04:59:55,275 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33306
# NLI Test Acc : 0.32950
# 2019-07-12 05:00:10,997 - INFO - ******************************************************
# 2019-07-12 05:00:10,998 - INFO - Updates: 2928
# 2019-07-12 05:00:12,581 - INFO - Updates: 2976
# 2019-07-12 05:00:15,439 - INFO - Updates: 3024
# 2019-07-12 05:00:17,309 - INFO - Updates: 3072
# 2019-07-12 05:00:18,798 - INFO - Updates: 3120
# 2019-07-12 05:00:20,385 - INFO - Updates: 3168
# 2019-07-12 05:00:22,273 - INFO - Updates: 3216
# 2019-07-12 05:00:23,965 - INFO - Updates: 3264
# 2019-07-12 05:00:25,745 - INFO - Updates: 3312
# 2019-07-12 05:00:28,551 - INFO - Updates: 3360
# 2019-07-12 05:00:29,141 - INFO - Seq2Seq Examples Processed : 3360 snli Loss : 5.39450 Num snli minibatches : 9
# 2019-07-12 05:00:29,217 - INFO - Round: 70 NLI Epoch : 0 NLI Examples Processed : 384 NLI Loss : 1.09081
# 2019-07-12 05:00:29,328 - INFO - Average time per minibatch : 1.81391
# 2019-07-12 05:00:29,371 - INFO - ############################
# 2019-07-12 05:00:29,372 - INFO - ##### Evaluating model #####
# 2019-07-12 05:00:29,372 - INFO - ############################
# 2019-07-12 05:01:54,398 - INFO - snli Validation Loss : 6.170
# 2019-07-12 05:01:54,400 - INFO - Best Validation Loss: 6.170159339904785
# 2019-07-12 05:01:54,400 - INFO - Monitor epoch: 7 Validation Loss:  6.170 Min Validation Epoch: 7 Loss : 6.170
# 2019-07-12 05:01:54,400 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33814
# NLI Test Acc : 0.34304
# 2019-07-12 05:02:10,227 - INFO - ******************************************************
# 2019-07-12 05:02:10,228 - INFO - Updates: 3408
# 2019-07-12 05:02:11,737 - INFO - Updates: 3456
# 2019-07-12 05:02:13,307 - INFO - Updates: 3504
# 2019-07-12 05:02:15,247 - INFO - Updates: 3552
# 2019-07-12 05:02:16,880 - INFO - Updates: 3600
# 2019-07-12 05:02:19,004 - INFO - Updates: 3648
# 2019-07-12 05:02:20,603 - INFO - Updates: 3696
# 2019-07-12 05:02:22,264 - INFO - Updates: 3744
# 2019-07-12 05:02:26,731 - INFO - Updates: 3792
# 2019-07-12 05:02:29,295 - INFO - Updates: 3840
# 2019-07-12 05:02:30,238 - INFO - Seq2Seq Examples Processed : 3840 snli Loss : 5.21222 Num snli minibatches : 9
# 2019-07-12 05:02:30,295 - INFO - Round: 80 NLI Epoch : 0 NLI Examples Processed : 432 NLI Loss : 1.07286
# 2019-07-12 05:02:30,349 - INFO - Average time per minibatch : 2.00064
# 2019-07-12 05:02:30,402 - INFO - ############################
# 2019-07-12 05:02:30,402 - INFO - ##### Evaluating model #####
# 2019-07-12 05:02:30,402 - INFO - ############################
# 2019-07-12 05:03:59,525 - INFO - snli Validation Loss : 6.090
# 2019-07-12 05:03:59,526 - INFO - Best Validation Loss: 6.090085983276367
# 2019-07-12 05:03:59,526 - INFO - Monitor epoch: 8 Validation Loss:  6.090 Min Validation Epoch: 8 Loss : 6.090
# 2019-07-12 05:03:59,526 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.38346
# NLI Test Acc : 0.38039
# 2019-07-12 05:04:15,265 - INFO - ******************************************************
# 2019-07-12 05:04:15,265 - INFO - Updates: 3888
# 2019-07-12 05:04:17,819 - INFO - Updates: 3936
# 2019-07-12 05:04:19,682 - INFO - Updates: 3984
# 2019-07-12 05:04:21,264 - INFO - Updates: 4032
# 2019-07-12 05:04:25,496 - INFO - Updates: 4080
# 2019-07-12 05:04:28,813 - INFO - Updates: 4128
# 2019-07-12 05:04:32,689 - INFO - Updates: 4176
# 2019-07-12 05:04:38,097 - INFO - Updates: 4224
# 2019-07-12 05:04:40,378 - INFO - Updates: 4272
# 2019-07-12 05:04:41,866 - INFO - Updates: 4320
# 2019-07-12 05:04:42,477 - INFO - Seq2Seq Examples Processed : 4320 snli Loss : 5.11506 Num snli minibatches : 9
# 2019-07-12 05:04:42,561 - INFO - Round: 90 NLI Epoch : 0 NLI Examples Processed : 480 NLI Loss : 1.20099
# 2019-07-12 05:04:42,707 - INFO - Average time per minibatch : 2.72076
# 2019-07-12 05:04:42,764 - INFO - ############################
# 2019-07-12 05:04:42,764 - INFO - ##### Evaluating model #####
# 2019-07-12 05:04:42,765 - INFO - ############################
# 2019-07-12 05:06:07,857 - INFO - snli Validation Loss : 6.048
# 2019-07-12 05:06:07,858 - INFO - Best Validation Loss: 6.047607421875
# 2019-07-12 05:06:07,858 - INFO - Monitor epoch: 9 Validation Loss:  6.048 Min Validation Epoch: 9 Loss : 6.048
# 2019-07-12 05:06:07,858 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33824
# NLI Test Acc : 0.34253
# 2019-07-12 05:06:23,626 - INFO - ******************************************************
# 2019-07-12 05:06:23,627 - INFO - Updates: 4368
# 2019-07-12 05:06:25,351 - INFO - Updates: 4416
# 2019-07-12 05:06:28,963 - INFO - Updates: 4464
# 2019-07-12 05:06:30,496 - INFO - Updates: 4512
# 2019-07-12 05:06:33,644 - INFO - Updates: 4560
# 2019-07-12 05:06:35,711 - INFO - Updates: 4608
# 2019-07-12 05:06:37,369 - INFO - Updates: 4656
# 2019-07-12 05:06:40,405 - INFO - Updates: 4704
# 2019-07-12 05:06:41,907 - INFO - Updates: 4752
# 2019-07-12 05:06:43,325 - INFO - Updates: 4800
# 2019-07-12 05:06:44,054 - INFO - Seq2Seq Examples Processed : 4800 snli Loss : 5.38293 Num snli minibatches : 9
# 2019-07-12 05:06:44,115 - INFO - Round: 100 NLI Epoch : 0 NLI Examples Processed : 528 NLI Loss : 1.11708
# 2019-07-12 05:06:44,255 - INFO - Average time per minibatch : 2.04233
# 2019-07-12 05:06:44,307 - INFO - ############################
# 2019-07-12 05:06:44,307 - INFO - ##### Evaluating model #####
# 2019-07-12 05:06:44,307 - INFO - ############################
# 2019-07-12 05:08:09,844 - INFO - snli Validation Loss : 5.997
# 2019-07-12 05:08:09,845 - INFO - Best Validation Loss: 5.9965691566467285
# 2019-07-12 05:08:09,845 - INFO - Monitor epoch: 10 Validation Loss:  5.997 Min Validation Epoch: 10 Loss : 5.997
# 2019-07-12 05:08:09,845 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.36486
# NLI Test Acc : 0.36737
# 2019-07-12 05:08:25,564 - INFO - ******************************************************
# 2019-07-12 05:08:25,565 - INFO - Updates: 4848
# 2019-07-12 05:08:27,819 - INFO - Updates: 4896
# 2019-07-12 05:08:30,250 - INFO - Updates: 4944
# 2019-07-12 05:08:32,233 - INFO - Updates: 4992
# 2019-07-12 05:08:35,564 - INFO - Updates: 5040
# 2019-07-12 05:08:39,491 - INFO - Updates: 5088
# 2019-07-12 05:08:40,958 - INFO - Updates: 5136
# 2019-07-12 05:08:44,866 - INFO - Updates: 5184
# 2019-07-12 05:08:50,325 - INFO - Updates: 5232
# 2019-07-12 05:08:52,066 - INFO - Updates: 5280
# 2019-07-12 05:08:52,705 - INFO - Seq2Seq Examples Processed : 5280 snli Loss : 5.10642 Num snli minibatches : 9
# 2019-07-12 05:08:52,790 - INFO - Round: 110 NLI Epoch : 0 NLI Examples Processed : 576 NLI Loss : 1.11160
# 2019-07-12 05:08:52,864 - INFO - Average time per minibatch : 2.71362
# 2019-07-12 05:08:52,922 - INFO - ############################
# 2019-07-12 05:08:52,922 - INFO - ##### Evaluating model #####
# 2019-07-12 05:08:52,922 - INFO - ############################
# 2019-07-12 05:10:18,170 - INFO - snli Validation Loss : 5.884
# 2019-07-12 05:10:18,171 - INFO - Best Validation Loss: 5.883915901184082
# 2019-07-12 05:10:18,171 - INFO - Monitor epoch: 11 Validation Loss:  5.884 Min Validation Epoch: 11 Loss : 5.884
# 2019-07-12 05:10:18,171 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35917
# NLI Test Acc : 0.36034
# 2019-07-12 05:10:33,924 - INFO - ******************************************************
# 2019-07-12 05:10:33,924 - INFO - Updates: 5328
# 2019-07-12 05:10:35,550 - INFO - Updates: 5376
# 2019-07-12 05:10:37,314 - INFO - Updates: 5424
# 2019-07-12 05:10:38,799 - INFO - Updates: 5472
# 2019-07-12 05:10:42,199 - INFO - Updates: 5520
# 2019-07-12 05:10:44,032 - INFO - Updates: 5568
# 2019-07-12 05:10:45,499 - INFO - Updates: 5616
# 2019-07-12 05:10:49,486 - INFO - Updates: 5664
# 2019-07-12 05:10:54,219 - INFO - Updates: 5712
# 2019-07-12 05:10:55,966 - INFO - Updates: 5760
# 2019-07-12 05:10:57,787 - INFO - Seq2Seq Examples Processed : 5760 snli Loss : 4.98631 Num snli minibatches : 9
# 2019-07-12 05:10:57,859 - INFO - Round: 120 NLI Epoch : 0 NLI Examples Processed : 624 NLI Loss : 1.07396
# 2019-07-12 05:10:57,952 - INFO - Average time per minibatch : 2.38584
# 2019-07-12 05:10:58,010 - INFO - ############################
# 2019-07-12 05:10:58,010 - INFO - ##### Evaluating model #####
# 2019-07-12 05:10:58,010 - INFO - ############################
# 2019-07-12 05:12:23,307 - INFO - snli Validation Loss : 5.871
# 2019-07-12 05:12:23,308 - INFO - Best Validation Loss: 5.87059211730957
# 2019-07-12 05:12:23,308 - INFO - Monitor epoch: 12 Validation Loss:  5.871 Min Validation Epoch: 12 Loss : 5.871
# 2019-07-12 05:12:23,309 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33306
# NLI Test Acc : 0.32960
# 2019-07-12 05:12:39,048 - INFO - ******************************************************
# 2019-07-12 05:12:39,048 - INFO - Updates: 5808
# 2019-07-12 05:12:40,649 - INFO - Updates: 5856
# 2019-07-12 05:12:42,156 - INFO - Updates: 5904
# 2019-07-12 05:12:43,863 - INFO - Updates: 5952
# 2019-07-12 05:12:45,543 - INFO - Updates: 6000
# 2019-07-12 05:12:47,140 - INFO - Updates: 6048
# 2019-07-12 05:12:48,641 - INFO - Updates: 6096
# 2019-07-12 05:12:50,408 - INFO - Updates: 6144
# 2019-07-12 05:12:52,423 - INFO - Updates: 6192
# 2019-07-12 05:12:54,220 - INFO - Updates: 6240
# 2019-07-12 05:12:56,974 - INFO - Seq2Seq Examples Processed : 6240 snli Loss : 4.84451 Num snli minibatches : 9
# 2019-07-12 05:12:57,029 - INFO - Round: 130 NLI Epoch : 0 NLI Examples Processed : 672 NLI Loss : 1.14676
# 2019-07-12 05:12:57,074 - INFO - Average time per minibatch : 1.79222
# 2019-07-12 05:12:57,116 - INFO - ############################
# 2019-07-12 05:12:57,116 - INFO - ##### Evaluating model #####
# 2019-07-12 05:12:57,116 - INFO - ############################
# WARNING - Retrying (Retry(total=2, connect=3, read=2, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(60, 'ETIMEDOUT')",))': /azureml/ExperimentRun/dcid.pytorch-gensen_1562904169_d0dbdced/azureml-logs/70_driver_log_rank_0.txt?sv=2018-03-28&sr=b&sig=MjHQOIKxJRiWHxv8IowRlzRtyyhADTbn9W146pD4yJ8%3D&st=2019-07-12T05%3A03%3A25Z&se=2019-07-12T13%3A13%3A25Z&sp=r
# 2019-07-12 05:14:24,463 - INFO - snli Validation Loss : 5.721
# 2019-07-12 05:14:24,464 - INFO - Best Validation Loss: 5.720923900604248
# 2019-07-12 05:14:24,464 - INFO - Monitor epoch: 13 Validation Loss:  5.721 Min Validation Epoch: 13 Loss : 5.721
# 2019-07-12 05:14:24,464 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35562
# NLI Test Acc : 0.34670
# 2019-07-12 05:14:40,259 - INFO - ******************************************************
# 2019-07-12 05:14:40,259 - INFO - Updates: 6288
# 2019-07-12 05:14:43,096 - INFO - Updates: 6336
# 2019-07-12 05:14:44,943 - INFO - Updates: 6384
# 2019-07-12 05:14:47,439 - INFO - Updates: 6432
# 2019-07-12 05:14:49,060 - INFO - Updates: 6480
# 2019-07-12 05:14:53,443 - INFO - Updates: 6528
# 2019-07-12 05:14:57,645 - INFO - Updates: 6576
# 2019-07-12 05:15:00,181 - INFO - Updates: 6624
# 2019-07-12 05:15:01,702 - INFO - Updates: 6672
# 2019-07-12 05:15:05,800 - INFO - Updates: 6720
# 2019-07-12 05:15:06,392 - INFO - Seq2Seq Examples Processed : 6720 snli Loss : 4.98342 Num snli minibatches : 9
# 2019-07-12 05:15:06,444 - INFO - Round: 140 NLI Epoch : 0 NLI Examples Processed : 720 NLI Loss : 1.07715
# 2019-07-12 05:15:06,505 - INFO - Average time per minibatch : 2.61282
# 2019-07-12 05:15:06,547 - INFO - ############################
# 2019-07-12 05:15:06,548 - INFO - ##### Evaluating model #####
# 2019-07-12 05:15:06,548 - INFO - ############################
# 2019-07-12 05:16:32,063 - INFO - snli Validation Loss : 5.693
# 2019-07-12 05:16:32,064 - INFO - Best Validation Loss: 5.692910194396973
# 2019-07-12 05:16:32,064 - INFO - Monitor epoch: 14 Validation Loss:  5.693 Min Validation Epoch: 14 Loss : 5.693
# 2019-07-12 05:16:32,064 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35572
# NLI Test Acc : 0.35922
# 2019-07-12 05:16:47,791 - INFO - ******************************************************
# 2019-07-12 05:16:47,791 - INFO - Updates: 6768
# 2019-07-12 05:16:54,146 - INFO - Updates: 6816
# 2019-07-12 05:16:57,156 - INFO - Updates: 6864
# 2019-07-12 05:16:58,621 - INFO - Updates: 6912
# 2019-07-12 05:17:00,110 - INFO - Updates: 6960
# 2019-07-12 05:17:01,765 - INFO - Updates: 7008
# 2019-07-12 05:17:03,605 - INFO - Updates: 7056
# 2019-07-12 05:17:05,149 - INFO - Updates: 7104
# 2019-07-12 05:17:06,747 - INFO - Updates: 7152
# 2019-07-12 05:17:08,364 - INFO - Updates: 7200
# 2019-07-12 05:17:08,949 - INFO - Seq2Seq Examples Processed : 7200 snli Loss : 4.97665 Num snli minibatches : 9
# 2019-07-12 05:17:08,997 - INFO - Round: 150 NLI Epoch : 0 NLI Examples Processed : 768 NLI Loss : 1.09425
# 2019-07-12 05:17:09,050 - INFO - Average time per minibatch : 2.11540
# 2019-07-12 05:17:09,150 - INFO - ############################
# 2019-07-12 05:17:09,150 - INFO - ##### Evaluating model #####
# 2019-07-12 05:17:09,150 - INFO - ############################
# 2019-07-12 05:18:34,965 - INFO - snli Validation Loss : 5.671
# 2019-07-12 05:18:34,966 - INFO - Best Validation Loss: 5.671082496643066
# 2019-07-12 05:18:34,967 - INFO - Monitor epoch: 15 Validation Loss:  5.671 Min Validation Epoch: 15 Loss : 5.671
# 2019-07-12 05:18:34,967 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.40144
# NLI Test Acc : 0.39841
# 2019-07-12 05:18:50,706 - INFO - ******************************************************
# 2019-07-12 05:18:50,707 - INFO - Updates: 7248
# 2019-07-12 05:18:52,325 - INFO - Updates: 7296
# 2019-07-12 05:18:54,025 - INFO - Updates: 7344
# 2019-07-12 05:18:55,569 - INFO - Updates: 7392
# 2019-07-12 05:18:57,948 - INFO - Updates: 7440
# 2019-07-12 05:18:59,552 - INFO - Updates: 7488
# 2019-07-12 05:19:02,391 - INFO - Updates: 7536
# 2019-07-12 05:19:04,124 - INFO - Updates: 7584
# 2019-07-12 05:19:05,803 - INFO - Updates: 7632
# 2019-07-12 05:19:07,364 - INFO - Updates: 7680
# 2019-07-12 05:19:07,963 - INFO - Seq2Seq Examples Processed : 7680 snli Loss : 4.67540 Num snli minibatches : 9
# 2019-07-12 05:19:08,014 - INFO - Round: 160 NLI Epoch : 0 NLI Examples Processed : 816 NLI Loss : 1.08444
# 2019-07-12 05:19:08,083 - INFO - Average time per minibatch : 1.72521
# 2019-07-12 05:19:08,125 - INFO - ############################
# 2019-07-12 05:19:08,126 - INFO - ##### Evaluating model #####
# 2019-07-12 05:19:08,126 - INFO - ############################
# 2019-07-12 05:20:33,429 - INFO - snli Validation Loss : 5.632
# 2019-07-12 05:20:33,430 - INFO - Best Validation Loss: 5.631965637207031
# 2019-07-12 05:20:33,430 - INFO - Monitor epoch: 16 Validation Loss:  5.632 Min Validation Epoch: 16 Loss : 5.632
# 2019-07-12 05:20:33,431 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.39464
# NLI Test Acc : 0.39566
# 2019-07-12 05:20:49,181 - INFO - ******************************************************
# 2019-07-12 05:20:49,181 - INFO - Updates: 7728
# 2019-07-12 05:20:53,173 - INFO - Updates: 7776
# 2019-07-12 05:20:54,740 - INFO - Updates: 7824
# 2019-07-12 05:20:56,394 - INFO - Updates: 7872
# 2019-07-12 05:20:59,065 - INFO - Updates: 7920
# 2019-07-12 05:21:00,602 - INFO - Updates: 7968
# 2019-07-12 05:21:02,215 - INFO - Updates: 8016
# 2019-07-12 05:21:03,759 - INFO - Updates: 8064
# 2019-07-12 05:21:06,138 - INFO - Updates: 8112
# 2019-07-12 05:21:07,929 - INFO - Updates: 8160
# 2019-07-12 05:21:08,546 - INFO - Seq2Seq Examples Processed : 8160 snli Loss : 4.95349 Num snli minibatches : 9
# 2019-07-12 05:21:08,591 - INFO - Round: 170 NLI Epoch : 0 NLI Examples Processed : 864 NLI Loss : 1.07961
# 2019-07-12 05:21:08,636 - INFO - Average time per minibatch : 1.93606
# 2019-07-12 05:21:08,678 - INFO - ############################
# 2019-07-12 05:21:08,678 - INFO - ##### Evaluating model #####
# 2019-07-12 05:21:08,678 - INFO - ############################
# 2019-07-12 05:22:33,901 - INFO - snli Validation Loss : 5.616
# 2019-07-12 05:22:33,902 - INFO - Best Validation Loss: 5.616095542907715
# 2019-07-12 05:22:33,903 - INFO - Monitor epoch: 17 Validation Loss:  5.616 Min Validation Epoch: 17 Loss : 5.616
# 2019-07-12 05:22:33,903 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35440
# NLI Test Acc : 0.35454
# 2019-07-12 05:22:49,654 - INFO - ******************************************************
# 2019-07-12 05:22:49,654 - INFO - Updates: 8208
# 2019-07-12 05:22:54,452 - INFO - Updates: 8256
# 2019-07-12 05:22:56,920 - INFO - Updates: 8304
# 2019-07-12 05:22:58,493 - INFO - Updates: 8352
# 2019-07-12 05:23:00,171 - INFO - Updates: 8400
# 2019-07-12 05:23:01,689 - INFO - Updates: 8448
# 2019-07-12 05:23:03,242 - INFO - Updates: 8496
# 2019-07-12 05:23:05,301 - INFO - Updates: 8544
# 2019-07-12 05:23:07,139 - INFO - Updates: 8592
# 2019-07-12 05:23:08,738 - INFO - Updates: 8640
# 2019-07-12 05:23:09,363 - INFO - Seq2Seq Examples Processed : 8640 snli Loss : 4.80288 Num snli minibatches : 9
# 2019-07-12 05:23:09,406 - INFO - Round: 180 NLI Epoch : 0 NLI Examples Processed : 912 NLI Loss : 1.13220
# 2019-07-12 05:23:09,446 - INFO - Average time per minibatch : 1.97047
# 2019-07-12 05:23:09,538 - INFO - ############################
# 2019-07-12 05:23:09,539 - INFO - ##### Evaluating model #####
# 2019-07-12 05:23:09,539 - INFO - ############################
# WARNING - Retrying (Retry(total=2, connect=3, read=2, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(60, 'ETIMEDOUT')",))': /azureml/ExperimentRun/dcid.pytorch-gensen_1562904169_d0dbdced/azureml-logs/70_driver_log_rank_0.txt?sv=2018-03-28&sr=b&sig=GAfbNgURyLDsvn106ZvBFw5igYr9eoRZULJLpqJ8fAs%3D&st=2019-07-12T05%3A14%3A17Z&se=2019-07-12T13%3A24%3A17Z&sp=r
# 2019-07-12 05:24:35,051 - INFO - snli Validation Loss : 5.530
# 2019-07-12 05:24:35,051 - INFO - Best Validation Loss: 5.530186653137207
# 2019-07-12 05:24:35,051 - INFO - Monitor epoch: 18 Validation Loss:  5.530 Min Validation Epoch: 18 Loss : 5.530
# 2019-07-12 05:24:35,052 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.32991
# NLI Test Acc : 0.32858
# 2019-07-12 05:24:50,790 - INFO - ******************************************************
# 2019-07-12 05:24:50,790 - INFO - Updates: 8688
# 2019-07-12 05:24:52,326 - INFO - Updates: 8736
# 2019-07-12 05:24:53,910 - INFO - Updates: 8784
# 2019-07-12 05:24:55,568 - INFO - Updates: 8832
# 2019-07-12 05:24:57,561 - INFO - Updates: 8880
# 2019-07-12 05:24:59,114 - INFO - Updates: 8928
# 2019-07-12 05:25:00,788 - INFO - Updates: 8976
# 2019-07-12 05:25:02,920 - INFO - Updates: 9024
# 2019-07-12 05:25:04,453 - INFO - Updates: 9072
# 2019-07-12 05:25:06,085 - INFO - Updates: 9120
# 2019-07-12 05:25:06,692 - INFO - Seq2Seq Examples Processed : 9120 snli Loss : 4.50582 Num snli minibatches : 9
# 2019-07-12 05:25:06,739 - INFO - Round: 190 NLI Epoch : 0 NLI Examples Processed : 960 NLI Loss : 1.11752
# 2019-07-12 05:25:06,812 - INFO - Average time per minibatch : 1.58971
# 2019-07-12 05:25:06,858 - INFO - ############################
# 2019-07-12 05:25:06,858 - INFO - ##### Evaluating model #####
# 2019-07-12 05:25:06,858 - INFO - ############################
# 2019-07-12 05:26:32,539 - INFO - snli Validation Loss : 5.458
# 2019-07-12 05:26:32,539 - INFO - Best Validation Loss: 5.458092212677002
# 2019-07-12 05:26:32,540 - INFO - Monitor epoch: 19 Validation Loss:  5.458 Min Validation Epoch: 19 Loss : 5.458
# 2019-07-12 05:26:32,540 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35135
# NLI Test Acc : 0.35515
# 2019-07-12 05:26:48,315 - INFO - ******************************************************
# 2019-07-12 05:26:48,315 - INFO - Updates: 9168
# 2019-07-12 05:26:49,935 - INFO - Updates: 9216
# 2019-07-12 05:26:54,631 - INFO - Updates: 9264
# 2019-07-12 05:26:57,728 - INFO - Updates: 9312
# 2019-07-12 05:26:59,582 - INFO - Updates: 9360
# 2019-07-12 05:27:01,063 - INFO - Updates: 9408
# 2019-07-12 05:27:02,592 - INFO - Updates: 9456
# 2019-07-12 05:27:04,252 - INFO - Updates: 9504
# 2019-07-12 05:27:05,727 - INFO - Updates: 9552
# 2019-07-12 05:27:07,984 - INFO - Updates: 9600
# 2019-07-12 05:27:08,603 - INFO - Seq2Seq Examples Processed : 9600 snli Loss : 4.39530 Num snli minibatches : 9
# 2019-07-12 05:27:08,647 - INFO - Round: 200 NLI Epoch : 0 NLI Examples Processed : 1008 NLI Loss : 1.09907
# 2019-07-12 05:27:08,714 - INFO - Average time per minibatch : 2.02835
# 2019-07-12 05:27:08,758 - INFO - ############################
# 2019-07-12 05:27:08,758 - INFO - ##### Evaluating model #####
# 2019-07-12 05:27:08,758 - INFO - ############################
# 2019-07-12 05:28:33,948 - INFO - snli Validation Loss : 5.495
# 2019-07-12 05:28:33,948 - INFO - Best Validation Loss: 5.494926452636719
# 2019-07-12 05:28:33,949 - INFO - Monitor epoch: 20 Validation Loss:  5.495 Min Validation Epoch: 19 Loss : 5.458
# 2019-07-12 05:28:33,949 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33337
# NLI Test Acc : 0.33021
# 2019-07-12 05:28:49,696 - INFO - ******************************************************
# 2019-07-12 05:28:49,697 - INFO - Updates: 9648
# 2019-07-12 05:28:52,162 - INFO - Updates: 9696
# 2019-07-12 05:28:58,371 - INFO - Updates: 9744
# 2019-07-12 05:29:00,085 - INFO - Updates: 9792
# 2019-07-12 05:29:01,708 - INFO - Updates: 9840
# 2019-07-12 05:29:03,596 - INFO - Updates: 9888
# 2019-07-12 05:29:07,503 - INFO - Updates: 9936
# 2019-07-12 05:29:10,271 - INFO - Updates: 9984
# 2019-07-12 05:29:11,897 - INFO - Updates: 10032
# 2019-07-12 05:29:13,528 - INFO - Updates: 10080
# 2019-07-12 05:29:14,881 - INFO - Seq2Seq Examples Processed : 10080 snli Loss : 4.78625 Num snli minibatches : 9
# 2019-07-12 05:29:14,942 - INFO - Round: 210 NLI Epoch : 0 NLI Examples Processed : 1056 NLI Loss : 1.09587
# 2019-07-12 05:29:14,988 - INFO - Average time per minibatch : 2.51800
# 2019-07-12 05:29:15,051 - INFO - ############################
# 2019-07-12 05:29:15,051 - INFO - ##### Evaluating model #####
# 2019-07-12 05:29:15,051 - INFO - ############################
# 2019-07-12 05:30:40,391 - INFO - snli Validation Loss : 5.452
# 2019-07-12 05:30:40,392 - INFO - Best Validation Loss: 5.452297210693359
# 2019-07-12 05:30:40,392 - INFO - Monitor epoch: 21 Validation Loss:  5.452 Min Validation Epoch: 21 Loss : 5.452
# 2019-07-12 05:30:40,392 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.37116
# NLI Test Acc : 0.37083
# 2019-07-12 05:30:56,187 - INFO - ******************************************************
# 2019-07-12 05:30:56,188 - INFO - Updates: 10128
# 2019-07-12 05:30:57,848 - INFO - Updates: 10176
# 2019-07-12 05:30:59,631 - INFO - Updates: 10224
# 2019-07-12 05:31:01,216 - INFO - Updates: 10272
# 2019-07-12 05:31:03,455 - INFO - Updates: 10320
# 2019-07-12 05:31:05,073 - INFO - Updates: 10368
# 2019-07-12 05:31:06,911 - INFO - Updates: 10416
# 2019-07-12 05:31:08,835 - INFO - Updates: 10464
# 2019-07-12 05:31:12,331 - INFO - Updates: 10512
# 2019-07-12 05:31:14,740 - INFO - Updates: 10560
# 2019-07-12 05:31:15,354 - INFO - Seq2Seq Examples Processed : 10560 snli Loss : 4.53924 Num snli minibatches : 9
# 2019-07-12 05:31:15,399 - INFO - Round: 220 NLI Epoch : 0 NLI Examples Processed : 1104 NLI Loss : 1.09968
# 2019-07-12 05:31:15,440 - INFO - Average time per minibatch : 1.91621
# 2019-07-12 05:31:15,487 - INFO - ############################
# 2019-07-12 05:31:15,488 - INFO - ##### Evaluating model #####
# 2019-07-12 05:31:15,488 - INFO - ############################
# 2019-07-12 05:32:40,737 - INFO - snli Validation Loss : 5.418
# 2019-07-12 05:32:40,737 - INFO - Best Validation Loss: 5.417891502380371
# 2019-07-12 05:32:40,738 - INFO - Monitor epoch: 22 Validation Loss:  5.418 Min Validation Epoch: 22 Loss : 5.418
# 2019-07-12 05:32:40,738 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33926
# NLI Test Acc : 0.34304
# 2019-07-12 05:32:56,489 - INFO - ******************************************************
# 2019-07-12 05:32:56,489 - INFO - Updates: 10608
# 2019-07-12 05:32:57,991 - INFO - Updates: 10656
# 2019-07-12 05:32:59,601 - INFO - Updates: 10704
# 2019-07-12 05:33:03,529 - INFO - Updates: 10752
# 2019-07-12 05:33:05,154 - INFO - Updates: 10800
# 2019-07-12 05:33:11,233 - INFO - Updates: 10848
# 2019-07-12 05:33:12,833 - INFO - Updates: 10896
# 2019-07-12 05:33:15,219 - INFO - Updates: 10944
# 2019-07-12 05:33:16,787 - INFO - Updates: 10992
# 2019-07-12 05:33:18,211 - INFO - Updates: 11040
# 2019-07-12 05:33:18,830 - INFO - Seq2Seq Examples Processed : 11040 snli Loss : 4.31053 Num snli minibatches : 9
# 2019-07-12 05:33:18,891 - INFO - Round: 230 NLI Epoch : 0 NLI Examples Processed : 1152 NLI Loss : 1.10091
# 2019-07-12 05:33:18,947 - INFO - Average time per minibatch : 2.23363
# 2019-07-12 05:33:19,001 - INFO - ############################
# 2019-07-12 05:33:19,002 - INFO - ##### Evaluating model #####
# 2019-07-12 05:33:19,002 - INFO - ############################
# 2019-07-12 05:34:44,885 - INFO - snli Validation Loss : 5.398
# 2019-07-12 05:34:44,886 - INFO - Best Validation Loss: 5.3984575271606445
# 2019-07-12 05:34:44,886 - INFO - Monitor epoch: 23 Validation Loss:  5.398 Min Validation Epoch: 23 Loss : 5.398
# 2019-07-12 05:34:44,886 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.36172
# NLI Test Acc : 0.36879
# 2019-07-12 05:35:00,640 - INFO - ******************************************************
# 2019-07-12 05:35:00,640 - INFO - Updates: 11088
# 2019-07-12 05:35:04,797 - INFO - Updates: 11136
# 2019-07-12 05:35:09,099 - INFO - Updates: 11184
# 2019-07-12 05:35:11,911 - INFO - Updates: 11232
# 2019-07-12 05:35:18,331 - INFO - Updates: 11280
# 2019-07-12 05:35:20,138 - INFO - Updates: 11328
# 2019-07-12 05:35:21,652 - INFO - Updates: 11376
# 2019-07-12 05:35:23,031 - INFO - Updates: 11424
# 2019-07-12 05:35:24,617 - INFO - Updates: 11472
# 2019-07-12 05:35:26,151 - INFO - Updates: 11520
# 2019-07-12 05:35:26,742 - INFO - Seq2Seq Examples Processed : 11520 snli Loss : 4.42585 Num snli minibatches : 9
# 2019-07-12 05:35:26,820 - INFO - Round: 240 NLI Epoch : 0 NLI Examples Processed : 1200 NLI Loss : 1.09637
# 2019-07-12 05:35:26,899 - INFO - Average time per minibatch : 2.60975
# 2019-07-12 05:35:26,987 - INFO - ############################
# 2019-07-12 05:35:26,987 - INFO - ##### Evaluating model #####
# 2019-07-12 05:35:26,987 - INFO - ############################
# 2019-07-12 05:36:52,429 - INFO - snli Validation Loss : 5.422
# 2019-07-12 05:36:52,429 - INFO - Best Validation Loss: 5.42218017578125
# 2019-07-12 05:36:52,430 - INFO - Monitor epoch: 24 Validation Loss:  5.422 Min Validation Epoch: 23 Loss : 5.398
# 2019-07-12 05:36:52,430 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.42268
# NLI Test Acc : 0.42182
# 2019-07-12 05:37:08,209 - INFO - ******************************************************
# 2019-07-12 05:37:08,210 - INFO - Updates: 11568
# 2019-07-12 05:37:09,911 - INFO - Updates: 11616
# 2019-07-12 05:37:11,441 - INFO - Updates: 11664
# 2019-07-12 05:37:12,992 - INFO - Updates: 11712
# 2019-07-12 05:37:14,814 - INFO - Updates: 11760
# 2019-07-12 05:37:16,850 - INFO - Updates: 11808
# 2019-07-12 05:37:19,568 - INFO - Updates: 11856
# 2019-07-12 05:37:23,480 - INFO - Updates: 11904
# 2019-07-12 05:37:25,073 - INFO - Updates: 11952
# 2019-07-12 05:37:26,723 - INFO - Updates: 12000
# 2019-07-12 05:37:27,402 - INFO - Seq2Seq Examples Processed : 12000 snli Loss : 4.32208 Num snli minibatches : 9
# 2019-07-12 05:37:27,514 - INFO - Round: 250 NLI Epoch : 0 NLI Examples Processed : 1248 NLI Loss : 1.09709
# 2019-07-12 05:37:27,573 - INFO - Average time per minibatch : 1.91886
# 2019-07-12 05:37:27,629 - INFO - ############################
# 2019-07-12 05:37:27,629 - INFO - ##### Evaluating model #####
# 2019-07-12 05:37:27,629 - INFO - ############################
# 2019-07-12 05:38:53,313 - INFO - snli Validation Loss : 5.330
# 2019-07-12 05:38:53,314 - INFO - Best Validation Loss: 5.330007553100586
# 2019-07-12 05:38:53,314 - INFO - Monitor epoch: 25 Validation Loss:  5.330 Min Validation Epoch: 25 Loss : 5.330
# 2019-07-12 05:38:53,315 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.34881
# NLI Test Acc : 0.34853
# 2019-07-12 05:39:09,119 - INFO - ******************************************************
# 2019-07-12 05:39:09,120 - INFO - Updates: 12048
# 2019-07-12 05:39:13,963 - INFO - Updates: 12096
# 2019-07-12 05:39:18,590 - INFO - Updates: 12144
# 2019-07-12 05:39:20,175 - INFO - Updates: 12192
# 2019-07-12 05:39:22,322 - INFO - Updates: 12240
# 2019-07-12 05:39:24,164 - INFO - Updates: 12288
# 2019-07-12 05:39:28,046 - INFO - Updates: 12336
# 2019-07-12 05:39:29,763 - INFO - Updates: 12384
# 2019-07-12 05:39:31,473 - INFO - Updates: 12432
# 2019-07-12 05:39:36,090 - INFO - Updates: 12480
# 2019-07-12 05:39:37,828 - INFO - Seq2Seq Examples Processed : 12480 snli Loss : 4.50231 Num snli minibatches : 9
# 2019-07-12 05:39:37,896 - INFO - Round: 260 NLI Epoch : 0 NLI Examples Processed : 1296 NLI Loss : 1.09259
# 2019-07-12 05:39:38,028 - INFO - Average time per minibatch : 2.87047
# 2019-07-12 05:39:38,070 - INFO - ############################
# 2019-07-12 05:39:38,070 - INFO - ##### Evaluating model #####
# 2019-07-12 05:39:38,070 - INFO - ############################
# 2019-07-12 05:41:03,669 - INFO - snli Validation Loss : 5.276
# 2019-07-12 05:41:03,669 - INFO - Best Validation Loss: 5.276036262512207
# 2019-07-12 05:41:03,670 - INFO - Monitor epoch: 26 Validation Loss:  5.276 Min Validation Epoch: 26 Loss : 5.276
# 2019-07-12 05:41:03,670 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.34180
# NLI Test Acc : 0.33724
# 2019-07-12 05:41:19,395 - INFO - ******************************************************
# 2019-07-12 05:41:19,395 - INFO - Updates: 12528
# 2019-07-12 05:41:20,820 - INFO - Updates: 12576
# 2019-07-12 05:41:22,474 - INFO - Updates: 12624
# 2019-07-12 05:41:24,099 - INFO - Updates: 12672
# 2019-07-12 05:41:25,615 - INFO - Updates: 12720
# 2019-07-12 05:41:27,254 - INFO - Updates: 12768
# 2019-07-12 05:41:28,702 - INFO - Updates: 12816
# 2019-07-12 05:41:30,292 - INFO - Updates: 12864
# 2019-07-12 05:41:32,044 - INFO - Updates: 12912
# 2019-07-12 05:41:33,676 - INFO - Updates: 12960
# 2019-07-12 05:41:34,273 - INFO - Seq2Seq Examples Processed : 12960 snli Loss : 3.93501 Num snli minibatches : 9
# 2019-07-12 05:41:34,317 - INFO - Round: 270 NLI Epoch : 0 NLI Examples Processed : 1344 NLI Loss : 1.09626
# 2019-07-12 05:41:34,376 - INFO - Average time per minibatch : 1.48734
# 2019-07-12 05:41:34,416 - INFO - ############################
# 2019-07-12 05:41:34,417 - INFO - ##### Evaluating model #####
# 2019-07-12 05:41:34,417 - INFO - ############################
# 2019-07-12 05:42:59,853 - INFO - snli Validation Loss : 5.145
# 2019-07-12 05:42:59,854 - INFO - Best Validation Loss: 5.145166397094727
# 2019-07-12 05:42:59,854 - INFO - Monitor epoch: 27 Validation Loss:  5.145 Min Validation Epoch: 27 Loss : 5.145
# 2019-07-12 05:42:59,854 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.37990
# NLI Test Acc : 0.37673
# ...
# 2019-07-12 05:49:45,099 - INFO - Round: 310 NLI Epoch : 0 NLI Examples Processed : 1536 NLI Loss : 1.09813
# 2019-07-12 05:49:45,142 - INFO - Average time per minibatch : 2.32403
# 2019-07-12 05:49:45,286 - INFO - ############################
# 2019-07-12 05:49:45,286 - INFO - ##### Evaluating model #####
# 2019-07-12 05:49:45,286 - INFO - ############################
# 2019-07-12 05:51:10,873 - INFO - snli Validation Loss : 5.135
# 2019-07-12 05:51:10,874 - INFO - Best Validation Loss: 5.1349334716796875
# 2019-07-12 05:51:10,874 - INFO - Monitor epoch: 31 Validation Loss:  5.135 Min Validation Epoch: 30 Loss : 5.120
# 2019-07-12 05:51:10,874 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.33621
# NLI Test Acc : 0.33428
# 2019-07-12 05:51:26,604 - INFO - ******************************************************
# 2019-07-12 05:51:26,604 - INFO - Updates: 14928
# 2019-07-12 05:51:29,104 - INFO - Updates: 14976
# 2019-07-12 05:51:31,867 - INFO - Updates: 15024
# 2019-07-12 05:51:33,716 - INFO - Updates: 15072
# 2019-07-12 05:51:38,756 - INFO - Updates: 15120
# 2019-07-12 05:51:42,556 - INFO - Updates: 15168
# 2019-07-12 05:51:45,439 - INFO - Updates: 15216
# 2019-07-12 05:51:49,415 - INFO - Updates: 15264
# 2019-07-12 05:51:51,179 - INFO - Updates: 15312
# 2019-07-12 05:51:52,690 - INFO - Updates: 15360
# 2019-07-12 05:51:53,279 - INFO - Seq2Seq Examples Processed : 15360 snli Loss : 4.27380 Num snli minibatches : 9
# 2019-07-12 05:51:53,324 - INFO - Round: 320 NLI Epoch : 0 NLI Examples Processed : 1584 NLI Loss : 1.09490
# 2019-07-12 05:51:53,371 - INFO - Average time per minibatch : 2.66711
# 2019-07-12 05:51:53,412 - INFO - ############################
# 2019-07-12 05:51:53,412 - INFO - ##### Evaluating model #####
# 2019-07-12 05:51:53,412 - INFO - ############################
# 2019-07-12 05:53:18,308 - INFO - snli Validation Loss : 5.159
# 2019-07-12 05:53:18,309 - INFO - Best Validation Loss: 5.158780574798584
# 2019-07-12 05:53:18,309 - INFO - Monitor epoch: 32 Validation Loss:  5.159 Min Validation Epoch: 30 Loss : 5.120
# 2019-07-12 05:53:18,309 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.37309
# NLI Test Acc : 0.37836
# 2019-07-12 05:53:34,075 - INFO - ******************************************************
# 2019-07-12 05:53:34,076 - INFO - Updates: 15408
# 2019-07-12 05:53:35,536 - INFO - Updates: 15456
# 2019-07-12 05:53:37,097 - INFO - Updates: 15504
# 2019-07-12 05:53:38,982 - INFO - Updates: 15552
# 2019-07-12 05:53:43,946 - INFO - Updates: 15600
# 2019-07-12 05:53:46,339 - INFO - Updates: 15648
# 2019-07-12 05:53:48,548 - INFO - Updates: 15696
# 2019-07-12 05:53:50,214 - INFO - Updates: 15744
# 2019-07-12 05:53:51,866 - INFO - Updates: 15792
# 2019-07-12 05:53:53,852 - INFO - Updates: 15840
# 2019-07-12 05:53:54,462 - INFO - Seq2Seq Examples Processed : 15840 snli Loss : 4.05280 Num snli minibatches : 9
# 2019-07-12 05:53:54,527 - INFO - Round: 330 NLI Epoch : 0 NLI Examples Processed : 1632 NLI Loss : 1.05934
# 2019-07-12 05:53:54,641 - INFO - Average time per minibatch : 2.03821
# 2019-07-12 05:53:54,704 - INFO - ############################
# 2019-07-12 05:53:54,704 - INFO - ##### Evaluating model #####
# 2019-07-12 05:53:54,704 - INFO - ############################
# WARNING - Retrying (Retry(total=2, connect=3, read=2, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(60, 'ETIMEDOUT')",))': /azureml/ExperimentRun/dcid.pytorch-gensen_1562904169_d0dbdced/azureml-logs/70_driver_log_rank_0.txt?sv=2018-03-28&sr=b&sig=CqvGcNDlA9RIsWZPnyVpt80UEizKcpdLBgrYFYMX%2F6o%3D&st=2019-07-12T05%3A44%3A24Z&se=2019-07-12T13%3A54%3A24Z&sp=r
# 2019-07-12 05:55:19,771 - INFO - snli Validation Loss : 5.106
# 2019-07-12 05:55:19,771 - INFO - Best Validation Loss: 5.105717658996582
# 2019-07-12 05:55:19,772 - INFO - Monitor epoch: 33 Validation Loss:  5.106 Min Validation Epoch: 33 Loss : 5.106
# 2019-07-12 05:55:19,772 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35775
# NLI Test Acc : 0.35637
# 2019-07-12 05:55:35,503 - INFO - ******************************************************
# 2019-07-12 05:55:35,503 - INFO - Updates: 15888
# 2019-07-12 05:55:37,079 - INFO - Updates: 15936
# 2019-07-12 05:55:38,695 - INFO - Updates: 15984
# 2019-07-12 05:55:40,750 - INFO - Updates: 16032
# 2019-07-12 05:55:42,310 - INFO - Updates: 16080
# 2019-07-12 05:55:43,868 - INFO - Updates: 16128
# 2019-07-12 05:55:45,434 - INFO - Updates: 16176
# 2019-07-12 05:55:48,233 - INFO - Updates: 16224
# 2019-07-12 05:55:50,061 - INFO - Updates: 16272
# 2019-07-12 05:55:51,632 - INFO - Updates: 16320
# 2019-07-12 05:55:52,305 - INFO - Seq2Seq Examples Processed : 16320 snli Loss : 3.94878 Num snli minibatches : 9
# 2019-07-12 05:55:52,466 - INFO - Round: 340 NLI Epoch : 0 NLI Examples Processed : 1680 NLI Loss : 1.06824
# 2019-07-12 05:55:52,617 - INFO - Average time per minibatch : 1.67984
# 2019-07-12 05:55:52,672 - INFO - ############################
# 2019-07-12 05:55:52,673 - INFO - ##### Evaluating model #####
# 2019-07-12 05:55:52,673 - INFO - ############################
# 2019-07-12 05:57:17,757 - INFO - snli Validation Loss : 5.134
# 2019-07-12 05:57:17,757 - INFO - Best Validation Loss: 5.133836269378662
# 2019-07-12 05:57:17,757 - INFO - Monitor epoch: 34 Validation Loss:  5.134 Min Validation Epoch: 33 Loss : 5.106
# 2019-07-12 05:57:17,757 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.35735
# NLI Test Acc : 0.35647
# 2019-07-12 05:57:33,481 - INFO - ******************************************************
# 2019-07-12 05:57:33,481 - INFO - Updates: 16368
# 2019-07-12 05:57:37,027 - INFO - Updates: 16416
# 2019-07-12 05:57:38,547 - INFO - Updates: 16464
# 2019-07-12 05:57:40,988 - INFO - Updates: 16512
# 2019-07-12 05:57:43,545 - INFO - Updates: 16560
# 2019-07-12 05:57:45,115 - INFO - Updates: 16608
# 2019-07-12 05:57:46,762 - INFO - Updates: 16656
# 2019-07-12 05:57:48,700 - INFO - Updates: 16704
# 2019-07-12 05:57:50,853 - INFO - Updates: 16752
# 2019-07-12 05:57:52,360 - INFO - Updates: 16800
# 2019-07-12 05:57:52,971 - INFO - Seq2Seq Examples Processed : 16800 snli Loss : 4.36578 Num snli minibatches : 9
# 2019-07-12 05:57:53,027 - INFO - Round: 350 NLI Epoch : 0 NLI Examples Processed : 1728 NLI Loss : 1.08616
# 2019-07-12 05:57:53,082 - INFO - Average time per minibatch : 1.94857
# 2019-07-12 05:57:53,136 - INFO - ############################
# 2019-07-12 05:57:53,136 - INFO - ##### Evaluating model #####
# 2019-07-12 05:57:53,136 - INFO - ############################
# 2019-07-12 05:59:18,393 - INFO - snli Validation Loss : 5.053
# 2019-07-12 05:59:18,394 - INFO - Best Validation Loss: 5.0533318519592285
# 2019-07-12 05:59:18,394 - INFO - Monitor epoch: 35 Validation Loss:  5.053 Min Validation Epoch: 35 Loss : 5.053
# 2019-07-12 05:59:18,394 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.43020
# NLI Test Acc : 0.42651
# 2019-07-12 05:59:34,148 - INFO - ******************************************************
# 2019-07-12 05:59:34,148 - INFO - Updates: 16848
# 2019-07-12 05:59:35,826 - INFO - Updates: 16896
# 2019-07-12 05:59:37,331 - INFO - Updates: 16944
# 2019-07-12 05:59:38,885 - INFO - Updates: 16992
# 2019-07-12 05:59:40,694 - INFO - Updates: 17040
# 2019-07-12 05:59:42,217 - INFO - Updates: 17088
# 2019-07-12 05:59:43,824 - INFO - Updates: 17136
# 2019-07-12 05:59:45,632 - INFO - Updates: 17184
# 2019-07-12 05:59:47,702 - INFO - Updates: 17232
# 2019-07-12 05:59:49,335 - INFO - Updates: 17280
# 2019-07-12 05:59:49,912 - INFO - Seq2Seq Examples Processed : 17280 snli Loss : 4.31533 Num snli minibatches : 9
# 2019-07-12 05:59:49,957 - INFO - Round: 360 NLI Epoch : 0 NLI Examples Processed : 1776 NLI Loss : 1.07322
# 2019-07-12 05:59:50,020 - INFO - Average time per minibatch : 1.57596
# 2019-07-12 05:59:50,061 - INFO - ############################
# 2019-07-12 05:59:50,062 - INFO - ##### Evaluating model #####
# 2019-07-12 05:59:50,062 - INFO - ############################
# 2019-07-12 06:01:15,234 - INFO - snli Validation Loss : 4.964
# 2019-07-12 06:01:15,235 - INFO - Best Validation Loss: 4.9639482498168945
# 2019-07-12 06:01:15,235 - INFO - Monitor epoch: 36 Validation Loss:  4.964 Min Validation Epoch: 36 Loss : 4.964
# 2019-07-12 06:01:15,235 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.42573
# NLI Test Acc : 0.42396
# 2019-07-12 06:01:30,973 - INFO - ******************************************************
# 2019-07-12 06:01:30,974 - INFO - Updates: 17328
# 2019-07-12 06:01:32,551 - INFO - Updates: 17376
# 2019-07-12 06:01:34,178 - INFO - Updates: 17424
# 2019-07-12 06:01:35,848 - INFO - Updates: 17472
# 2019-07-12 06:01:37,325 - INFO - Updates: 17520
# 2019-07-12 06:01:38,926 - INFO - Updates: 17568
# 2019-07-12 06:01:43,541 - INFO - Updates: 17616
# 2019-07-12 06:01:45,224 - INFO - Updates: 17664
# 2019-07-12 06:01:47,639 - INFO - Updates: 17712
# 2019-07-12 06:01:49,449 - INFO - Updates: 17760
# 2019-07-12 06:01:50,041 - INFO - Seq2Seq Examples Processed : 17760 snli Loss : 4.42077 Num snli minibatches : 9
# 2019-07-12 06:01:50,121 - INFO - Round: 370 NLI Epoch : 0 NLI Examples Processed : 1824 NLI Loss : 1.07547
# 2019-07-12 06:01:50,229 - INFO - Average time per minibatch : 1.90637
# 2019-07-12 06:01:50,271 - INFO - ############################
# 2019-07-12 06:01:50,272 - INFO - ##### Evaluating model #####
# 2019-07-12 06:01:50,272 - INFO - ############################
# 2019-07-12 06:03:15,684 - INFO - snli Validation Loss : 5.034
# 2019-07-12 06:03:15,684 - INFO - Best Validation Loss: 5.0338945388793945
# 2019-07-12 06:03:15,685 - INFO - Monitor epoch: 37 Validation Loss:  5.034 Min Validation Epoch: 36 Loss : 4.964
# 2019-07-12 06:03:15,685 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.41526
# NLI Test Acc : 0.42569
# 2019-07-12 06:03:31,437 - INFO - ******************************************************
# 2019-07-12 06:03:31,438 - INFO - Updates: 17808
# 2019-07-12 06:03:32,930 - INFO - Updates: 17856
# 2019-07-12 06:03:34,500 - INFO - Updates: 17904
# 2019-07-12 06:03:36,152 - INFO - Updates: 17952
# 2019-07-12 06:03:37,994 - INFO - Updates: 18000
# 2019-07-12 06:03:39,441 - INFO - Updates: 18048
# 2019-07-12 06:03:41,173 - INFO - Updates: 18096
# 2019-07-12 06:03:44,011 - INFO - Updates: 18144
# 2019-07-12 06:03:45,621 - INFO - Updates: 18192
# 2019-07-12 06:03:48,659 - INFO - Updates: 18240
# 2019-07-12 06:03:49,261 - INFO - Seq2Seq Examples Processed : 18240 snli Loss : 4.13274 Num snli minibatches : 9
# 2019-07-12 06:03:49,320 - INFO - Round: 380 NLI Epoch : 0 NLI Examples Processed : 1872 NLI Loss : 1.07320
# 2019-07-12 06:03:49,482 - INFO - Average time per minibatch : 1.78188
# 2019-07-12 06:03:49,535 - INFO - ############################
# 2019-07-12 06:03:49,536 - INFO - ##### Evaluating model #####
# 2019-07-12 06:03:49,536 - INFO - ############################
# 2019-07-12 06:05:14,995 - INFO - snli Validation Loss : 4.889
# 2019-07-12 06:05:14,995 - INFO - Best Validation Loss: 4.888514518737793
# 2019-07-12 06:05:14,995 - INFO - Monitor epoch: 38 Validation Loss:  4.889 Min Validation Epoch: 38 Loss : 4.889
# 2019-07-12 06:05:14,996 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.42613
# NLI Test Acc : 0.43170
# 2019-07-12 06:05:30,790 - INFO - ******************************************************
# 2019-07-12 06:05:30,790 - INFO - Updates: 18288
# 2019-07-12 06:05:33,511 - INFO - Updates: 18336
# 2019-07-12 06:05:37,633 - INFO - Updates: 18384
# 2019-07-12 06:05:40,045 - INFO - Updates: 18432
# 2019-07-12 06:05:42,888 - INFO - Updates: 18480
# 2019-07-12 06:05:45,898 - INFO - Updates: 18528
# 2019-07-12 06:05:47,402 - INFO - Updates: 18576
# 2019-07-12 06:05:48,958 - INFO - Updates: 18624
# 2019-07-12 06:05:50,637 - INFO - Updates: 18672
# 2019-07-12 06:05:52,339 - INFO - Updates: 18720
# 2019-07-12 06:05:52,924 - INFO - Seq2Seq Examples Processed : 18720 snli Loss : 3.98208 Num snli minibatches : 9
# 2019-07-12 06:05:52,985 - INFO - Round: 390 NLI Epoch : 0 NLI Examples Processed : 1920 NLI Loss : 1.09049
# 2019-07-12 06:05:53,051 - INFO - Average time per minibatch : 2.21301
# 2019-07-12 06:05:53,112 - INFO - ############################
# 2019-07-12 06:05:53,112 - INFO - ##### Evaluating model #####
# 2019-07-12 06:05:53,113 - INFO - ############################
# 2019-07-12 06:07:18,526 - INFO - snli Validation Loss : 4.950
# 2019-07-12 06:07:18,527 - INFO - Best Validation Loss: 4.9497504234313965
# 2019-07-12 06:07:18,527 - INFO - Monitor epoch: 39 Validation Loss:  4.950 Min Validation Epoch: 38 Loss : 4.889
# 2019-07-12 06:07:18,527 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.43426
# NLI Test Acc : 0.44137
# 2019-07-12 06:07:34,271 - INFO - ******************************************************
# 2019-07-12 06:07:34,271 - INFO - Updates: 18768
# 2019-07-12 06:07:35,793 - INFO - Updates: 18816
# 2019-07-12 06:07:37,216 - INFO - Updates: 18864
# 2019-07-12 06:07:38,735 - INFO - Updates: 18912
# 2019-07-12 06:07:40,371 - INFO - Updates: 18960
# 2019-07-12 06:07:43,876 - INFO - Updates: 19008
# 2019-07-12 06:07:46,566 - INFO - Updates: 19056
# 2019-07-12 06:07:48,025 - INFO - Updates: 19104
# 2019-07-12 06:07:49,648 - INFO - Updates: 19152
# 2019-07-12 06:07:51,215 - INFO - Updates: 19200
# 2019-07-12 06:07:51,850 - INFO - Seq2Seq Examples Processed : 19200 snli Loss : 3.88864 Num snli minibatches : 9
# 2019-07-12 06:07:51,905 - INFO - Round: 400 NLI Epoch : 0 NLI Examples Processed : 1968 NLI Loss : 1.05207
# 2019-07-12 06:07:52,010 - INFO - Average time per minibatch : 1.75743
# 2019-07-12 06:07:52,064 - INFO - ############################
# 2019-07-12 06:07:52,064 - INFO - ##### Evaluating model #####
# 2019-07-12 06:07:52,064 - INFO - ############################
# 2019-07-12 06:09:17,321 - INFO - snli Validation Loss : 5.052
# 2019-07-12 06:09:17,322 - INFO - Best Validation Loss: 5.051584720611572
# 2019-07-12 06:09:17,322 - INFO - Monitor epoch: 40 Validation Loss:  5.052 Min Validation Epoch: 38 Loss : 4.889
# 2019-07-12 06:09:17,322 - INFO - Evaluating on NLI
# NLI Dev Acc : 0.40093
# NLI Test Acc : 0.40421
# 2019-07-12 06:09:33,081 - INFO - ******************************************************
# 2019-07-12 06:09:33,082 - INFO - Updates: 19248
# 2019-07-12 06:09:36,039 - INFO - Updates: 19296
# 2019-07-12 06:09:37,651 - INFO - Updates: 19344
# 2019-07-12 06:09:43,843 - INFO - Updates: 19392
# 2019-07-12 06:09:45,584 - INFO - Updates: 19440
# 2019-07-12 06:09:47,175 - INFO - Updates: 19488
# 2019-07-12 06:09:50,267 - INFO - Updates: 19536
# 2019-07-12 06:09:51,775 - INFO - Updates: 19584
# 2019-07-12 06:09:53,358 - INFO - Updates: 19632
# 2019-07-12 06:09:54,753 - INFO - Updates: 19680
# 2019-07-12 06:09:55,346 - INFO - Seq2Seq Examples Processed : 19680 snli Loss : 4.02460 Num snli minibatches : 9
# 2019-07-12 06:09:55,492 - INFO - Round: 410 NLI Epoch : 0 NLI Examples Processed : 2016 NLI Loss : 1.09868
# 2019-07-12 06:09:55,606 - INFO - Average time per minibatch : 2.22599
# 2019-07-12 06:09:55,669 - INFO - ############################
# 2019-07-12 06:09:55,669 - INFO - ##### Evaluating model #####
# 2019-07-12 06:09:55,669 - INFO - ############################
# 2019-07-12 06:11:21,087 - INFO - snli Validation Loss : 5.158
# 2019-07-12 06:11:21,088 - INFO - Best Validation Loss: 5.157825469970703
# 2019-07-12 06:11:21,088 - INFO - Monitor epoch: 41 Validation Loss:  5.158 Min Validation Epoch: 38 Loss : 4.889
# 2019-07-12 06:11:21,088 - INFO - Saving model ...
# 2019-07-12 06:11:26,183 - INFO - ##### Training stopped at ##### 4.888515
# 2019-07-12 06:11:26,184 - INFO - ##### Training Time ##### 5020.641723 seconds
#
#
# The experiment completed successfully. Finalizing run...
# 2019-07-12 06:11:28,483 - INFO - Exiting context: UserExceptions
# 2019-07-12 06:11:28,483 - INFO - Exiting context: DaskOnBatch
# 2019-07-12 06:11:28,483 - INFO - Exiting context: TrackUserError
# 2019-07-12 06:11:28,484 - INFO - Exiting context: OutputCollection
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 3 items cleaning up...
# Cleanup took 0.0030858516693115234 seconds
# 2019-07-12 06:11:28,560 - INFO - Exiting context: ProjectPythonPath
#
# Execution Summary
# =================
# RunId: pytorch-gensen_1562904169_d0dbdced
# Web View: https://mlworkspace.azure.ai/portal/subscriptions/15ae9cb6-95c1-483d-a0e3-b1a1a3b06324/resourceGroups/nlprg/providers/Microsoft.MachineLearningServices/workspaces/jihon/experiments/pytorch-gensen/runs/pytorch-gensen_1562904169_d0dbdced

# %% [markdown]
# ### 2.4.2 Interpret the Training Results
# The following chart shows the model validation loss with different node configurations on AmlCompute. We find that the minimum validation loss decreases as the number of nodes increases; that is, the performance scales with the number of nodes in the cluster.
#
# | Standard_NC6 | AML_1node | AML_2nodes | AML_4nodes | AML_8nodes |
# | --- | --- | --- | --- | --- |
# | min_val_loss | 4.81 | 4.78 | 4.77 | 4.58 |
#
# We also observe common tradeoffs associated with distributed training. We make use of [Horovod](https://github.com/horovod/horovod), a distributed training tool for many popular deep learning frameworks that enables parallelization of work across the nodes in the cluster. Distributed training decreases the time it takes for the model to converge in theory, but the model may also take more time in communicating with each node. Note that the communication time will eventually become negligible when training on larger and larger datasets, but being aware of this tradeoff is helpful for choosing the node configuration when training on smaller datasets.

# %% [markdown]
# # 3 Tune Model Hyperparameters
# Now that we've seen how to do a simple PyTorch training run using the SDK, let's see if we can further improve the accuracy of our model. We can optimize our model's hyperparameters using Azure Machine Learning's hyperparameter tuning capabilities.

# %% [markdown]
# ## 3.1 Start a Hyperparameter Sweep
# First, we define the hyperparameter space to sweep over. Since the training script uses a learning rate schedule to decay the learning rate every several epochs, we can tune the initial learning rate parameter. In this example we will use random sampling to try different configuration sets of hyperparameters to minimize our primary metric, the best validation loss.
#
# Then, we specify the early termination policy to use to early terminate poorly performing runs. Here we use the `BanditPolicy`, which terminates any run that doesn't fall within the slack factor of our primary evaluation metric. In this tutorial, we will apply this policy every epoch (since we report our the validation loss metric every epoch and `evaluation_interval=1`). Note that we explicitly define `delay_evaluation` such that the first policy evaluation does not occur until after the 10th epoch.
#
# Refer [here](https://docs.microsoft.com/azure/machine-learning/service/how-to-tune-hyperparameters#specify-an-early-termination-policy) for more information on the BanditPolicy and other policies available.

# %%
param_sampling = RandomParameterSampling({"learning_rate": uniform(0.0001, 0.001)})

early_termination_policy = BanditPolicy(
    slack_factor=0.15, evaluation_interval=1, delay_evaluation=10
)

hyperdrive_config = HyperDriveConfig(
    estimator=estimator,
    hyperparameter_sampling=param_sampling,
    policy=early_termination_policy,
    primary_metric_name="min_val_loss",
    primary_metric_goal=PrimaryMetricGoal.MINIMIZE,
    max_total_runs=8,
    max_concurrent_runs=4,
)

# %% [markdown]
# Finally, lauch the hyperparameter tuning job.

# %%
hyperdrive_run = experiment.submit(hyperdrive_config) # Start the HyperDrive run

# %% [markdown]
# ## 3.2 Monitor HyperDrive Runs
# We can monitor the progress of the runs with a Jupyter widget, or again block until the run has completed.

# %%
#RunDetails(hyperdrive_run).show()

# %%
_ = hyperdrive_run.wait_for_completion(show_output=AZUREML_VERBOSE) # Block until complete

# %% [markdown]
# ### 3.2.1 Interpret the Tuning Results
#
# The chart below shows 4 different threads running in parallel with different learning rates. The number of total runs is 8. We pick the best learning rate by minimizing the validation loss. The HyperDrive run automatically shows the tracking charts (example in the following) to facilitate visualization of the tuning process.
#
# ![Tuning](https://nlpbp.blob.core.windows.net/images/tuning.PNG)
#
# **From the results in section [2.3.5 Monitor your run](#2.4.1-Monitor-your-run), the best validation loss for 1 node is 4.81, but with tuning we can easily achieve better performance around 4.65.**

# %% [markdown]
# ## 3.3 Find the Best Model

# %% [markdown]
# Once all the runs complete, we can find the run that produced the model with the lowest loss.

# %%
best_run = hyperdrive_run.get_best_run_by_primary_metric()
best_run_metrics = best_run.get_metrics()
if AZUREML_VERBOSE:
    print(best_run)
    print(
        "Best Run:\n  Validation loss: {0:.5f} \n  Learning rate: {1:.5f} \n".format(
            best_run_metrics["best_val_loss"][-1], best_run_metrics["lr"]
        )
    )

# %% [markdown]
# ## References
#
# 1. Subramanian, Sandeep and Trischler, Adam and Bengio, Yoshua and Pal, Christopher J, [*Learning general purpose distributed sentence representations via large scale multi-task learning*](https://arxiv.org/abs/1804.00079), ICLR, 2018.
# 2. A. Conneau, D. Kiela, [*SentEval: An Evaluation Toolkit for Universal Sentence Representations*](https://arxiv.org/abs/1803.05449).
# 3. Semantic textual similarity. url: http://nlpprogress.com/english/semantic_textual_similarity.html
# 4. Minh-Thang Luong, Quoc V Le, Ilya Sutskever, Oriol Vinyals, and Lukasz Kaiser. [*Multi-task sequence to sequence learning*](https://arxiv.org/abs/1511.06114), 2015.
# 5. Bryan McCann, James Bradbury, Caiming Xiong, and Richard Socher. [*Learned in translation: Contextualized word vectors](https://arxiv.org/abs/1708.00107), 2017.
