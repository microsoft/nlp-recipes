# %%
# %load_ext autoreload
# %autoreload 2
from utils_nlp.dataset.cnndm import CNNDMSummarizationDatasetOrg
from utils_nlp.models.transformers.abstractive_summarization_seq2seq import S2SAbsSumProcessor, S2SAbstractiveSummarizer
# Out:
# [nltk_data] Downloading package punkt to /home/hlu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# I0120 23:06:57.841488 139733668775680 file_utils.py:35] PyTorch version 1.2.0 available.

# %%
import time

# %%
start = time.time()
train_ds, test_ds = CNNDMSummarizationDatasetOrg(top_n=1000)
print(time.time() - start)
# Out:
# I0121 00:58:48.989737 139733668775680 url_utils.py:77] File ./cnndm_data.zip already downloaded
# 7.213513135910034

# %%
for item in train_ds:
    print("source: " + item['src'])
    print("target: " + item['tgt'])
    print()

# %%
processor = S2SAbsSumProcessor()
train_dataset = processor.train_dataset_from_sum_ds(train_ds)
# Out:
# I0116 19:43:10.849705 139836880123648 tokenization_utils.py:398] loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-vocab.txt from cache at ./5e8a2b4893d13790ed4150ca1906be5f7a03d6c4ddf62296c383f6db42814db2.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# I0116 19:43:10.879660 139836880123648 utils.py:108] Loading features from cached file ./train_features

# %%
train_dataset.train_features[0]["source_ids"]
# Out:
# [9057,
#  112,
#  188,
#  3805,
#  131,
#  1130,
#  1412,
#  8291,
#  1103,
#  15555,
#  1116,
#  1326,
#  117,
#  13597,
#  12499,
#  1116,
#  2934,
#  1147,
#  5758,
#  1107,
#  4576,
#  2371,
#  1105,
#  19774,
#  1103,
#  2801,
#  1481,
#  1103,
#  1958,
#  119,
#  3446,
#  117,
#  17135,
#  14604,
#  1181,
#  152,
#  112,
#  9620,
#  2274,
#  4713,
#  1656,
#  170,
#  7237,
#  1187,
#  1242,
#  1104,
#  1103,
#  13944,
#  1132,
#  10883,
#  5178,
#  119,
#  1760,
#  1107,
#  7213,
#  6960,
#  1113,
#  1103,
#  107,
#  6278,
#  1837,
#  117,
#  107,
#  1187,
#  1242,
#  10883,
#  5178,
#  13944,
#  1132,
#  6960,
#  1107,
#  4916,
#  1196,
#  3443,
#  119,
#  26574,
#  10964,
#  2240,
#  117,
#  2631,
#  113,
#  13597,
#  114,
#  118,
#  118,
#  1109,
#  6948,
#  1837,
#  1104,
#  1103,
#  4916,
#  118,
#  4708,
#  1162,
#  3073,
#  19091,
#  1348,
#  13826,
#  3695,
#  1110,
#  9098,
#  1103,
#  107,
#  6278,
#  1837,
#  119,
#  107,
#  3446,
#  117,
#  13944,
#  1114,
#  1103,
# ...

# %%
abs_summarizer = S2SAbstractiveSummarizer(model_name="unilm-base-cased")
# Out:
# I0116 19:43:13.561590 139836880123648 configuration_utils.py:185] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/unilm/unilm-base-cased-config.json from cache at ./5a91666904992a7b95efe9beb184ffe0164ea54702089b2fac9ffb2109e9e0a9.f50cbf37bb3e2510e9ab70f869455d8e38c30739ca638c9b4f5a824801636362
# I0116 19:43:13.562647 139836880123648 configuration_utils.py:199] Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "label_smoothing": 0.0,
#   "layer_norm_eps": 1e-12,
#   "layer_norm_epsilon": 1e-05,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
# ...

# %%
abs_summarizer.fit(train_dataset=train_dataset)

# %%
abs_summarizer.save_model(global_step=1, fp16=False)
